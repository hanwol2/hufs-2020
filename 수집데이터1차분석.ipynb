# %% [markdown]
# <a href="https://colab.research.google.com/github/hanwol2/hufs-2020/blob/main/%EC%88%98%EC%A7%91%EB%8D%B0%EC%9D%B4%ED%84%B01%EC%B0%A8%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 환경 준비

# %%
# konlpy 설치하기
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 44.7MB/s
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/fd/96/1030895dea70855a2e1078e3fe0d6a63dcb7c212309e07dc9ee39d33af54/JPype1-1.1.2-cp36-cp36m-manylinux2010_x86_64.whl (450kB)
#      |████████████████████████████████| 460kB 32.8MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Collecting tweepy>=3.7.0
#   Downloading https://files.pythonhosted.org/packages/bb/7c/99d51f80f3b77b107ebae2634108717362c059a41384a1810d13e2429a81/tweepy-3.9.0-py2.py3-none-any.whl
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 9.7MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.18.5)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, tweepy, beautifulsoup4, konlpy
#   Found existing installation: tweepy 3.6.0
#     Uninstalling tweepy-3.6.0:
#       Successfully uninstalled tweepy-3.6.0
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.1.2 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2 tweepy-3.9.0

# %%
# konlpy를 실행하기
import konlpy

# %%
## pandas을 실행하기, 단 실행 별명을 pd로
import pandas as pd

# %% [markdown]
# # 데이터 불러오기

# %%
# 구글 드라이브 연결을 위한 기본 세팅 
# !pip install -U -q PyDrive
 
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
## 문서 ID로 실제 파일 불러오기

rawdata_downloaded = drive.CreateFile({'id': '1_9kPlfkMqMdv2BrOHWWBtsRtHuhpGNGC'})
rawdata_downloaded.GetContentFile('rawdata.csv')

# %%
# "rawdata.csv" 파일의 내용을 "원본데이터" 변수로 불러오기
원본데이터 = pd.read_csv('rawdata.csv', encoding='cp949')

# %%
# "원본데이터" 변수 내용 확인하기
원본데이터
# Out:
#      year  ...                                              lyric
# 0    2016  ...  Hey boy Make’ em whistle like a missile bomb b...
# 1    2016  ...  BLACKPINK in your area BLACKPINK in your area ...
# 2    2016  ...  우리 엄만 매일 내게 말했어 언제나 남자 조심하라고 사랑은 마치 불장난 같아서 다치...
# 3    2016  ...  툭하면 거친 말들로 내 맘에 상처를 내놓고 미안하단 말 한마디 없이 또 나 혼자 위...
# 4    2017  ...  너 뭔데 자꾸 생각나 자존심 상해 애가 타 얼굴이 뜨겁고 가슴은 계속 뛰어 내 몸이...
# ..    ...  ...                                                ...
# 560  2020  ...  뭘 자꾸 주저해 감정이 싹 틀 때 표현하는 방법은 여러 가지가 있지 하고 싶은 것 ...
# 561  2020  ...  Hey buddy 지금 몇 시야 늦잠 잤어 창밖을 보니 좋은 날씨야 허겁지겁 옷을 ...
# 562  2020  ...  아슬아슬하게 선을 타 Woo 넘을 듯 말 듯하게 맞닿은 Secret sign 간지러...
# 563  2020  ...  I’m ready for you 내 마음은 준비돼 있어 누가 뭐라 해도 신경 쓴 적...
# 564  2020  ...  내 사랑은 겨우 이것밖에 안 돼 안녕, 나의 기쁨이여 깊은 절망에도 항상 웃게 해 ...
#
# [565 rows x 6 columns]

# %% [markdown]
# # 형태소 분석

# %%
# konlpy(한국어형태소분석기) 중에서 Okt 실행하기
from konlpy.tag import Okt
okt = Okt()

# %%
# "원본데이터"를 대상으로 "okt"를 사용해서 형태소 분석하기
저장공간  = []
for index, row in 원본데이터.iterrows(): # 원본데이터의 컬럼(열)을 불러와서 반복할 준비!
    대상텍스트 = row[5] # 분석에서 사용할 텍스트 정보가 있는 열을 지정해준다. 주의! python은 0부터 시작한다!
    분류 = row[1] # 분석에서 사용할 분류 정보가 있는 열을 지정해준다. 주의! python은 0부터 시작한다!
    형태소 = list(okt.pos(대상텍스트)) # okt의 pos 기능을 활용해서 대상 텍스트를 형태소 분리한다.
    형태소종합 = pd.DataFrame.from_records(형태소) # 형태소에 저장된 내용을 데이터프레임 형태로 해서 형태소종합으로 저장한다.
    형태소종합['type'] = 분류 # 형태소종합에 분류정보를 추가한다.
    형태소종합['count'] = 1   # 형태소종합에 카운트정보를 추가한다.   
    저장공간.append(형태소종합) # 형태소종합의 내용을 종합하여 저장한다.

# %%
# "형태소" 변수의 저장 내용 확인
형태소
# Out:
# [('내', 'Noun'),
#  ('사랑', 'Noun'),
#  ('은', 'Josa'),
#  ('겨우', 'Noun'),
#  ('이', 'Determiner'),
#  ('것', 'Noun'),
#  ('밖에', 'Josa'),
#  ('안', 'Noun'),
#  ('돼', 'Verb'),
#  ('안녕', 'Noun'),
#  (',', 'Punctuation'),
#  ('나', 'Noun'),
#  ('의', 'Josa'),
#  ('기쁨', 'Noun'),
#  ('이여', 'Josa'),
#  ('깊은', 'Adjective'),
#  ('절망', 'Noun'),
#  ('에도', 'Josa'),
#  ('항상', 'Noun'),
#  ('웃게', 'Verb'),
#  ('해', 'Noun'),
#  ('By', 'Alpha'),
#  ('my', 'Alpha'),
#  ('side', 'Alpha'),
#  ('잠시', 'Noun'),
#  ('모든', 'Noun'),
#  ('걸', 'Noun'),
#  ('잊게', 'Verb'),
#  ('해', 'Noun'),
#  ('줘', 'Verb'),
#  ('아는', 'Verb'),
#  ('노랠', 'Adjective'),
#  ('틀', 'Noun'),
#  ('고', 'Josa'),
#  ('One', 'Alpha'),
#  ('step', 'Alpha'),
#  ('두', 'Noun'),
#  ('손', 'Noun'),
#  ('을', 'Josa'),
#  ('잡고', 'Noun'),
#  ('발', 'Noun'),
#  ('을', 'Josa'),
#  ('Two', 'Alpha'),
#  ('step', 'Alpha'),
#  ('어느새', 'Adjective'),
#  ('오늘', 'Noun'),
#  ('의', 'Josa'),
#  ('나', 'Noun'),
#  ('에게', 'Josa'),
#  ('내일', 'Noun'),
#  ('의', 'Josa'),
#  ('널', 'Noun'),
#  ('바라게', 'Verb'),
#  ('해', 'Noun'),
#  ('Baby', 'Alpha'),
#  ('It', 'Alpha'),
#  ("'", 'Punctuation'),
#  ('s', 'Alpha'),
#  ('alright', 'Alpha'),
#  ('Oh', 'Alpha'),
#  ('It', 'Alpha'),
#  ("'", 'Punctuation'),
#  ('s', 'Alpha'),
#  ('okay', 'Alpha'),
#  ('내', 'Noun'),
#  ('거짓말', 'Noun'),
#  ('다', 'Adverb'),
#  ('아는', 'Verb'),
#  ('건', 'Noun'),
#  ('너뿐이', 'Noun'),
#  ('라', 'Josa'),
#  (',', 'Punctuation'),
#  ('O', 'Alpha'),
#  ('ah', 'Alpha'),
#  ('더', 'Noun'),
#  ('고마워', 'Adjective'),
#  ('가끔', 'Noun'),
#  ('은', 'Josa'),
#  ('지쳐', 'Verb'),
#  ('고개', 'Noun'),
#  ('숙여', 'Verb'),
#  ('우는', 'Verb'),
#  ('널', 'Noun'),
#  ('볼', 'Noun'),
#  ('때', 'Noun'),
#  ('어쩔', 'Adverb'),
#  ('줄', 'Noun'),
#  ('모르는', 'Verb'),
#  ('난', 'Noun'),
#  ('뭘', 'Noun'),
#  ('할', 'Verb'),
#  ('수', 'Noun'),
#  ('있을까', 'Adjective'),
#  ('정말', 'Noun'),
#  ('미안해', 'Adjective'),
#  ('내', 'Noun'),
#  ('사랑', 'Noun'),
#  ('이', 'Josa'),
#  ('겨우', 'Noun'),
#  ('이', 'Determiner'),
#  ('것', 'Noun'),
#  ('밖에', 'Josa'),
#  ('안', 'Noun'),
#  ('돼', 'Verb'),
#  ('그래도', 'Adverb'),
#  ('내', 'Noun'),
#  ('곁', 'Noun'),
#  ('에', 'Josa'),
#  ('있어', 'Adjective'),
#  ('줘서', 'Verb'),
#  ('고마워', 'Adjective'),
#  ('My', 'Alpha'),
#  ('baby', 'Alpha'),
#  ('내', 'Noun'),
#  ('사랑', 'Noun'),
#  ('이', 'Josa'),
#  ('겨우', 'Noun'),
#  ('이', 'Determiner'),
#  ('것', 'Noun'),
#  ('밖에', 'Josa'),
#  ('안', 'Noun'),
#  ('돼도', 'Verb'),
#  ('어느', 'Adverb'),
#  ('겨울', 'Noun'),
#  ('에도', 'Josa'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('봄', 'Noun'),
#  ('이', 'Josa'),
#  ('될게', 'Verb'),
#  ('내', 'Noun'),
#  ('마음', 'Noun'),
#  ('이', 'Josa'),
#  ('겨우', 'Noun'),
#  ('이런', 'Adjective'),
#  ('말', 'Noun'),
#  ('해', 'Noun'),
#  ('쏟아지는', 'Verb'),
#  ('유성우', 'Noun'),
#  ('처럼', 'Josa'),
#  ('까만', 'Adjective'),
#  ('하늘', 'Noun'),
#  ('에', 'Josa'),
#  ('빛', 'Noun'),
#  ('이', 'Josa'),
#  ('돼', 'Verb'),
#  ('줘', 'Verb'),
#  ('I', 'Alpha'),
#  ('can', 'Alpha'),
#  ('do', 'Alpha'),
#  ('everything', 'Alpha'),
#  ('for', 'Alpha'),
#  ('you', 'Alpha'),
#  ('난', 'Noun'),
#  ('너', 'Noun'),
#  ('에게', 'Josa'),
#  ('뭐', 'Noun'),
#  ('든지', 'Josa'),
#  ('다', 'Adverb'),
#  ('주고', 'Verb'),
#  ('싶은', 'Verb'),
#  ('마음', 'Noun'),
#  ('만', 'Josa'),
#  ('커서', 'Noun'),
#  ('작아지는', 'Verb'),
#  ('나', 'Noun'),
#  ('는', 'Josa'),
#  ('받기만', 'Verb'),
#  ('하는', 'Verb'),
#  ('바보', 'Noun'),
#  ('어느새', 'Adjective'),
#  ('내', 'Noun'),
#  ('가', 'Josa'),
#  ('미워서', 'Verb'),
#  ('너', 'Noun'),
#  ('에게', 'Josa'),
#  ('더욱', 'Noun'),
#  ('미안해', 'Adjective'),
#  ('Baby', 'Alpha'),
#  ('It', 'Alpha'),
#  ("'", 'Punctuation'),
#  ('s', 'Alpha'),
#  ('alright', 'Alpha'),
#  ('Oh', 'Alpha'),
#  ('It', 'Alpha'),
#  ("'", 'Punctuation'),
#  ('s', 'Alpha'),
#  ('okay', 'Alpha'),
#  ('내', 'Noun'),
#  ('거짓말', 'Noun'),
#  ('다', 'Adverb'),
#  ('아는', 'Verb'),
#  ('건', 'Noun'),
#  ('너뿐이', 'Noun'),
#  ('라', 'Josa'),
#  (',', 'Punctuation'),
#  ('O', 'Alpha'),
#  ('ah', 'Alpha'),
#  ('더', 'Noun'),
#  ('고마워', 'Adjective'),
#  ('가끔', 'Noun'),
#  ('은', 'Josa'),
#  ('지쳐', 'Verb'),
#  ('고개', 'Noun'),
#  ('숙여', 'Verb'),
#  ('우는', 'Verb'),
#  ('널', 'Noun'),
#  ('볼', 'Noun'),
#  ('때', 'Noun'),
#  ('어쩔', 'Adverb'),
#  ('줄', 'Noun'),
#  ('모르는', 'Verb'),
#  ('난', 'Noun'),
#  ('뭘', 'Noun'),
#  ('할', 'Verb'),
#  ('수', 'Noun'),
#  ('있을까', 'Adjective'),
#  ('정말', 'Noun'),
#  ('미안해', 'Adjective'),
#  ('내', 'Noun'),
#  ('사랑', 'Noun'),
#  ('이', 'Josa'),
#  ('겨우', 'Noun'),
#  ('이', 'Determiner'),
#  ('것', 'Noun'),
#  ('밖에', 'Josa'),
#  ('안', 'Noun'),
#  ('돼', 'Verb'),
#  ('그래도', 'Adverb'),
#  ('내', 'Noun'),
#  ('곁', 'Noun'),
#  ('에', 'Josa'),
#  ('있어', 'Adjective'),
#  ('줘서', 'Verb'),
#  ('고마워', 'Adjective'),
#  ('My', 'Alpha'),
#  ('baby', 'Alpha'),
#  ('내', 'Noun'),
#  ('사랑', 'Noun'),
#  ('이', 'Josa'),
#  ('겨우', 'Noun'),
#  ('이', 'Determiner'),
#  ('것', 'Noun'),
#  ('밖에', 'Josa'),
#  ('안', 'Noun'),
#  ('돼도', 'Verb'),
#  ('어느', 'Adverb'),
#  ('겨울', 'Noun'),
#  ('에도', 'Josa'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('봄', 'Noun'),
#  ('이', 'Josa'),
#  ('될게', 'Verb'),
#  ('내', 'Noun'),
#  ('마음', 'Noun'),
#  ('이', 'Josa'),
#  ('겨우', 'Noun'),
#  ('이런', 'Adjective'),
#  ('말', 'Noun'),
#  ('해', 'Noun'),
#  ('어렵게', 'Adjective'),
#  ('내', 'Noun'),
#  ('마음', 'Noun'),
#  ('적은', 'Verb'),
#  ('이', 'Noun'),
#  ('노래', 'Noun'),
#  ('와', 'Josa'),
#  ('가사', 'Noun'),
#  ('뿐', 'Suffix'),
#  ('이지만', 'Josa'),
#  ('For', 'Alpha'),
#  ('you', 'Alpha'),
#  ('for', 'Alpha'),
#  ('you', 'Alpha'),
#  ('for', 'Alpha'),
#  ('you', 'Alpha'),
#  ('for', 'Alpha'),
#  ('you', 'Alpha'),
#  ('이', 'Noun'),
#  ('노랜', 'Noun'),
#  ('널', 'Noun'),
#  ('위해', 'Noun'),
#  ('불러', 'Verb'),
#  ('Tonight', 'Alpha'),
#  ('네', 'Noun'),
#  ('사랑', 'Noun'),
#  ('에', 'Josa'),
#  ('다가갈', 'Verb'),
#  ('수', 'Noun'),
#  ('있게', 'Adjective'),
#  ('내', 'Noun'),
#  ('사랑', 'Noun'),
#  ('이', 'Josa'),
#  ('겨우', 'Noun'),
#  ('이', 'Determiner'),
#  ('것', 'Noun'),
#  ('밖에', 'Josa'),
#  ('안', 'Noun'),
#  ('돼', 'Verb'),
#  ('그래도', 'Adverb'),
#  ('내', 'Noun'),
#  ('마음', 'Noun'),
#  ('은', 'Josa'),
#  ('변치', 'Noun'),
#  ('않아', 'Verb'),
#  ('너', 'Noun'),
#  ('에게만', 'Josa'),
#  ('Baby', 'Alpha'),
#  ('내', 'Noun'),
#  ('사랑', 'Noun'),
#  ('이', 'Josa'),
#  ('겨우', 'Noun'),
#  ('이', 'Determiner'),
#  ('것', 'Noun'),
#  ('밖에', 'Josa'),
#  ('안', 'Noun'),
#  ('돼도', 'Verb'),
#  ('비', 'Noun'),
#  ('내리는', 'Verb'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('우산', 'Noun'),
#  ('이', 'Josa'),
#  ('돼', 'Verb'),
#  ('줄', 'Noun'),
#  ('게', 'Josa'),
#  ('지켜줄게', 'Verb'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('모든', 'Noun'),
#  ('날', 'Noun'),
#  ('에', 'Josa')]

# %%
# "형태소종합" 변수의 저장 내용 확인
형태소종합
# Out:
#       0           1            type  count
# 0     내        Noun  SEVENTEEN(세븐틴)      1
# 1    사랑        Noun  SEVENTEEN(세븐틴)      1
# 2     은        Josa  SEVENTEEN(세븐틴)      1
# 3    겨우        Noun  SEVENTEEN(세븐틴)      1
# 4     이  Determiner  SEVENTEEN(세븐틴)      1
# ..   ..         ...             ...    ...
# 328   너        Noun  SEVENTEEN(세븐틴)      1
# 329   의        Josa  SEVENTEEN(세븐틴)      1
# 330  모든        Noun  SEVENTEEN(세븐틴)      1
# 331   날        Noun  SEVENTEEN(세븐틴)      1
# 332   에        Josa  SEVENTEEN(세븐틴)      1
#
# [333 rows x 4 columns]

# %%
# "저장공간" 변수의 저장 내용 확인
저장공간
# Out:
# [        0            1       type  count
#  0     Hey        Alpha  BLACKPINK      1
#  1     boy        Alpha  BLACKPINK      1
#  2    Make        Alpha  BLACKPINK      1
#  3       ’  Punctuation  BLACKPINK      1
#  4      em        Alpha  BLACKPINK      1
#  ..    ...          ...        ...    ...
#  389  show        Alpha  BLACKPINK      1
#  390    up        Alpha  BLACKPINK      1
#  391  blow        Alpha  BLACKPINK      1
#  392    up        Alpha  BLACKPINK      1
#  393    uh        Alpha  BLACKPINK      1
#
#  [394 rows x 4 columns],              0            1       type  count
#  0    BLACKPINK        Alpha  BLACKPINK      1
#  1           in        Alpha  BLACKPINK      1
#  2         your        Alpha  BLACKPINK      1
#  3         area        Alpha  BLACKPINK      1
#  4    BLACKPINK        Alpha  BLACKPINK      1
#  ..         ...          ...        ...    ...
#  430         go        Alpha  BLACKPINK      1
#  431        let        Alpha  BLACKPINK      1
#  432          '  Punctuation  BLACKPINK      1
#  433          s        Alpha  BLACKPINK      1
#  434         go        Alpha  BLACKPINK      1
#
#  [435 rows x 4 columns],          0      1       type  count
#  0       우리   Noun  BLACKPINK      1
#  1        엄   Noun  BLACKPINK      1
#  2        만   Josa  BLACKPINK      1
#  3       매일   Noun  BLACKPINK      1
#  4       내게   Verb  BLACKPINK      1
#  ..     ...    ...        ...    ...
#  271      밤   Noun  BLACKPINK      1
#  272      을   Josa  BLACKPINK      1
#  273     태워   Verb  BLACKPINK      1
#  274    버리게   Verb  BLACKPINK      1
#  275  whooo  Alpha  BLACKPINK      1
#
#  [276 rows x 4 columns],         0       1       type  count
#  0     툭하면    Noun  BLACKPINK      1
#  1      거친    Verb  BLACKPINK      1
#  2       말    Noun  BLACKPINK      1
#  3       들  Suffix  BLACKPINK      1
#  4       로    Josa  BLACKPINK      1
#  ..    ...     ...        ...    ...
#  301     곁    Noun  BLACKPINK      1
#  302     에    Josa  BLACKPINK      1
#  303  stay   Alpha  BLACKPINK      1
#  304  with   Alpha  BLACKPINK      1
#  305    me   Alpha  BLACKPINK      1
#
#  [306 rows x 4 columns],         0          1       type  count
#  0       너       Noun  BLACKPINK      1
#  1       뭔   Modifier  BLACKPINK      1
#  2       데       Noun  BLACKPINK      1
#  3      자꾸       Noun  BLACKPINK      1
#  4     생각나       Verb  BLACKPINK      1
#  ..    ...        ...        ...    ...
#  342    따윈       Noun  BLACKPINK      1
#  343    없는  Adjective  BLACKPINK      1
#  344     것       Noun  BLACKPINK      1
#  345    처럼       Josa  BLACKPINK      1
#  346  love      Alpha  BLACKPINK      1
#
#  [347 rows x 4 columns],        0            1       type  count
#  0     착한    Adjective  BLACKPINK      1
#  1     얼굴         Noun  BLACKPINK      1
#  2      에         Josa  BLACKPINK      1
#  3    그렇지    Adjective  BLACKPINK      1
#  4      못         Noun  BLACKPINK      1
#  ..   ...          ...        ...    ...
#  309   du        Alpha  BLACKPINK      1
#  310  ddu        Alpha  BLACKPINK      1
#  311    -  Punctuation  BLACKPINK      1
#  312   du        Alpha  BLACKPINK      1
#  313   du        Alpha  BLACKPINK      1
#
#  [314 rows x 4 columns],           0            1       type  count
#  0         [  Punctuation  BLACKPINK      1
#  1    JENNIE        Alpha  BLACKPINK      1
#  2         ]  Punctuation  BLACKPINK      1
#  3        If        Alpha  BLACKPINK      1
#  4       you        Alpha  BLACKPINK      1
#  ..      ...          ...        ...    ...
#  458     for        Alpha  BLACKPINK      1
#  459    real        Alpha  BLACKPINK      1
#  460  Really        Alpha  BLACKPINK      1
#  461  really        Alpha  BLACKPINK      1
#  462  really        Alpha  BLACKPINK      1
#
#  [463 rows x 4 columns],           0      1       type  count
#  0       떠나지   Verb  BLACKPINK      1
#  1         마   Noun  BLACKPINK      1
#  2      just  Alpha  BLACKPINK      1
#  3      stay  Alpha  BLACKPINK      1
#  4        지금   Noun  BLACKPINK      1
#  ..      ...    ...        ...    ...
#  386     bum  Alpha  BLACKPINK      1
#  387     bum  Alpha  BLACKPINK      1
#  388  whatta  Alpha  BLACKPINK      1
#  389     bum  Alpha  BLACKPINK      1
#  390     bum  Alpha  BLACKPINK      1
#
#  [391 rows x 4 columns],          0            1       type  count
#  0        [  Punctuation  BLACKPINK      1
#  1    JISOO        Alpha  BLACKPINK      1
#  2        ]  Punctuation  BLACKPINK      1
#  3      아쉬울    Adjective  BLACKPINK      1
#  4        것         Noun  BLACKPINK      1
#  ..     ...          ...        ...    ...
#  536    See        Alpha  BLACKPINK      1
#  537      u        Alpha  BLACKPINK      1
#  538  later        Alpha  BLACKPINK      1
#  539  maybe        Alpha  BLACKPINK      1
#  540  never        Alpha  BLACKPINK      1
#
#  [541 rows x 4 columns],         0            1       type  count
#  0      천사         Noun  BLACKPINK      1
#  1      같은    Adjective  BLACKPINK      1
#  2      Hi        Alpha  BLACKPINK      1
#  3       끝         Noun  BLACKPINK      1
#  4       엔         Josa  BLACKPINK      1
#  ..    ...          ...        ...    ...
#  301     ’  Punctuation  BLACKPINK      1
#  302     s        Alpha  BLACKPINK      1
#  303  kill        Alpha  BLACKPINK      1
#  304  this        Alpha  BLACKPINK      1
#  305  love        Alpha  BLACKPINK      1
#
#  [306 rows x 4 columns],         0      1       type  count
#  0      잠깐   Noun  BLACKPINK      1
#  1      누가   Noun  BLACKPINK      1
#  2      시간   Noun  BLACKPINK      1
#  3       을   Josa  BLACKPINK      1
#  4       좀   Noun  BLACKPINK      1
#  ..    ...    ...        ...    ...
#  269     본   Verb  BLACKPINK      1
#  270     네   Noun  BLACKPINK      1
#  271    기억   Noun  BLACKPINK      1
#  272     은   Josa  BLACKPINK      1
#  273  Blue  Alpha  BLACKPINK      1
#
#  [274 rows x 4 columns],       0         1       type  count
#  0    결론      Noun  BLACKPINK      1
#  1     이      Josa  BLACKPINK      1
#  2     뭔  Modifier  BLACKPINK      1
#  3     데      Noun  BLACKPINK      1
#  4     또      Noun  BLACKPINK      1
#  ..   ..       ...        ...    ...
#  436   너      Noun  BLACKPINK      1
#  437   를      Josa  BLACKPINK      1
#  438  잊을      Verb  BLACKPINK      1
#  439   거      Noun  BLACKPINK      1
#  440  라고      Josa  BLACKPINK      1
#
#  [441 rows x 4 columns],        0          1       type  count
#  0    시원한  Adjective  BLACKPINK      1
#  1     바람       Noun  BLACKPINK      1
#  2     부는       Verb  BLACKPINK      1
#  3     창가       Noun  BLACKPINK      1
#  4      에       Josa  BLACKPINK      1
#  ..   ...        ...        ...    ...
#  201    날       Noun  BLACKPINK      1
#  202   잊을       Verb  BLACKPINK      1
#  203   만큼       Noun  BLACKPINK      1
#  204   만은       Josa  BLACKPINK      1
#  205  아니길  Adjective  BLACKPINK      1
#
#  [206 rows x 4 columns],           0      1       type  count
#  0      Come  Alpha  BLACKPINK      1
#  1         a  Alpha  BLACKPINK      1
#  2    little  Alpha  BLACKPINK      1
#  3    closer  Alpha  BLACKPINK      1
#  4     cause  Alpha  BLACKPINK      1
#  ..      ...    ...        ...    ...
#  525   cream  Alpha  BLACKPINK      1
#  526     Ice  Alpha  BLACKPINK      1
#  527   cream  Alpha  BLACKPINK      1
#  528     Ice  Alpha  BLACKPINK      1
#  529   cream  Alpha  BLACKPINK      1
#
#  [530 rows x 4 columns],         0      1       type  count
#  0      보란   Verb  BLACKPINK      1
#  1      듯이   Noun  BLACKPINK      1
#  2    무너졌어   Verb  BLACKPINK      1
#  3      바닥   Noun  BLACKPINK      1
#  4       을   Josa  BLACKPINK      1
#  ..    ...    ...        ...    ...
#  351  that  Alpha  BLACKPINK      1
#  352   How  Alpha  BLACKPINK      1
#  353   you  Alpha  BLACKPINK      1
#  354  like  Alpha  BLACKPINK      1
#  355  that  Alpha  BLACKPINK      1
#
#  [356 rows x 4 columns],            0          1       type  count
#  0        영원한  Adjective  BLACKPINK      1
#  1          밤       Noun  BLACKPINK      1
#  2         창문       Noun  BLACKPINK      1
#  3         없는  Adjective  BLACKPINK      1
#  4          방       Noun  BLACKPINK      1
#  ..       ...        ...        ...    ...
#  368       re      Alpha  BLACKPINK      1
#  369    still      Alpha  BLACKPINK      1
#  370  looking      Alpha  BLACKPINK      1
#  371      for      Alpha  BLACKPINK      1
#  372     love      Alpha  BLACKPINK      1
#
#  [373 rows x 4 columns],           0          1       type  count
#  0       비슷한  Adjective  BLACKPINK      1
#  1         것       Noun  BLACKPINK      1
#  2        같지  Adjective  BLACKPINK      1
#  3        우린       Noun  BLACKPINK      1
#  4        뼛속       Noun  BLACKPINK      1
#  ..      ...        ...        ...    ...
#  314      so      Alpha  BLACKPINK      1
#  315  pretty      Alpha  BLACKPINK      1
#  316  pretty      Alpha  BLACKPINK      1
#  317  pretty      Alpha  BLACKPINK      1
#  318  pretty      Alpha  BLACKPINK      1
#
#  [319 rows x 4 columns],              0      1       type  count
#  0    BLACKPINK  Alpha  BLACKPINK      1
#  1        Cardi  Alpha  BLACKPINK      1
#  2         Tell  Alpha  BLACKPINK      1
#  3           me  Alpha  BLACKPINK      1
#  4        where  Alpha  BLACKPINK      1
#  ..         ...    ...        ...    ...
#  562        you  Alpha  BLACKPINK      1
#  563      wanna  Alpha  BLACKPINK      1
#  564       love  Alpha  BLACKPINK      1
#  565       this  Alpha  BLACKPINK      1
#  566       ahhh  Alpha  BLACKPINK      1
#
#  [567 rows x 4 columns],          0      1       type  count
#  0        I  Alpha  BLACKPINK      1
#  1     been  Alpha  BLACKPINK      1
#  2    known  Alpha  BLACKPINK      1
#  3       to  Alpha  BLACKPINK      1
#  4     kiss  Alpha  BLACKPINK      1
#  ..     ...    ...        ...    ...
#  358  crazy  Alpha  BLACKPINK      1
#  359      I  Alpha  BLACKPINK      1
#  360   love  Alpha  BLACKPINK      1
#  361    you  Alpha  BLACKPINK      1
#  362  crazy  Alpha  BLACKPINK      1
#
#  [363 rows x 4 columns],         0      1       type  count
#  0    Love  Alpha  BLACKPINK      1
#  1     How  Alpha  BLACKPINK      1
#  2     you  Alpha  BLACKPINK      1
#  3    love  Alpha  BLACKPINK      1
#  4      to  Alpha  BLACKPINK      1
#  ..    ...    ...        ...    ...
#  505  only  Alpha  BLACKPINK      1
#  506  love  Alpha  BLACKPINK      1
#  507    to  Alpha  BLACKPINK      1
#  508  hate  Alpha  BLACKPINK      1
#  509    me  Alpha  BLACKPINK      1
#
#  [510 rows x 4 columns],         0      1       type  count
#  0     애써서   Verb  BLACKPINK      1
#  1      활짝   Noun  BLACKPINK      1
#  2     웃었던   Verb  BLACKPINK      1
#  3       날   Noun  BLACKPINK      1
#  4       에   Josa  BLACKPINK      1
#  ..    ...    ...        ...    ...
#  422   got  Alpha  BLACKPINK      1
#  423     a  Alpha  BLACKPINK      1
#  424  shot  Alpha  BLACKPINK      1
#  425    on  Alpha  BLACKPINK      1
#  426    me  Alpha  BLACKPINK      1
#
#  [427 rows x 4 columns],          0            1                   type  count
#  0      Sou        Alpha  Lady Gaga & BLACKPINK      1
#  1        -  Punctuation  Lady Gaga & BLACKPINK      1
#  2     sour        Alpha  Lady Gaga & BLACKPINK      1
#  3    candy        Alpha  Lady Gaga & BLACKPINK      1
#  4      Sou        Alpha  Lady Gaga & BLACKPINK      1
#  ..     ...          ...                    ...    ...
#  342      a        Alpha  Lady Gaga & BLACKPINK      1
#  343   bite        Alpha  Lady Gaga & BLACKPINK      1
#  344     Uh        Alpha  Lady Gaga & BLACKPINK      1
#  345   Sour        Alpha  Lady Gaga & BLACKPINK      1
#  346  candy        Alpha  Lady Gaga & BLACKPINK      1
#
#  [347 rows x 4 columns],        0            1   type  count
#  0     모두         Noun  TWICE      1
#  1     나를         Verb  TWICE      1
#  2     가지         Noun  TWICE      1
#  3      고         Josa  TWICE      1
#  4     매일         Noun  TWICE      1
#  ..   ...          ...    ...    ...
#  409  OOH        Alpha  TWICE      1
#  410    -  Punctuation  TWICE      1
#  411  AHH        Alpha  TWICE      1
#  412   하게         Verb  TWICE      1
#  413    )  Punctuation  TWICE      1
#
#  [414 rows x 4 columns],          0      1   type  count
#  0      You  Alpha  TWICE      1
#  1    ready  Alpha  TWICE      1
#  2    girls  Alpha  TWICE      1
#  3       DJ  Alpha  TWICE      1
#  4     Drop  Alpha  TWICE      1
#  ..     ...    ...    ...    ...
#  317     해줘   Verb  TWICE      1
#  318     어서   Noun  TWICE      1
#  319     와서   Verb  TWICE      1
#  320     다시   Noun  TWICE      1
#  321     해줘   Verb  TWICE      1
#
#  [322 rows x 4 columns],          0            1   type  count
#  0      아이코  Exclamation  TWICE      1
#  1      맙소사  Exclamation  TWICE      1
#  2        왜         Noun  TWICE      1
#  3      이러니  Conjunction  TWICE      1
#  4        왜         Noun  TWICE      1
#  ..     ...          ...    ...    ...
#  291      I        Alpha  TWICE      1
#  292      '  Punctuation  TWICE      1
#  293      m        Alpha  TWICE      1
#  294  going        Alpha  TWICE      1
#  295  crazy        Alpha  TWICE      1
#
#  [296 rows x 4 columns],            0            1   type  count
#  0    Alright        Alpha  TWICE      1
#  1        뭐라고         Verb  TWICE      1
#  2          말         Noun  TWICE      1
#  3         할까         Verb  TWICE      1
#  4       두근두근       Adverb  TWICE      1
#  ..       ...          ...    ...    ...
#  329      for        Alpha  TWICE      1
#  330      you        Alpha  TWICE      1
#  331        (  Punctuation  TWICE      1
#  332    Truth        Alpha  TWICE      1
#  333        )  Punctuation  TWICE      1
#
#  [334 rows x 4 columns],          0           1   type  count
#  0       자다        Verb  TWICE      1
#  1        깬        Verb  TWICE      1
#  2      목소리        Noun  TWICE      1
#  3    헝클어진듯        Verb  TWICE      1
#  4        한  Determiner  TWICE      1
#  ..     ...         ...    ...    ...
#  255    Boy       Alpha  TWICE      1
#  256      U       Alpha  TWICE      1
#  257     My       Alpha  TWICE      1
#  258  Candy       Alpha  TWICE      1
#  259    Boy       Alpha  TWICE      1
#
#  [260 rows x 4 columns],          0          1   type  count
#  0    잔잔했었던  Adjective  TWICE      1
#  1        내       Noun  TWICE      1
#  2        맘       Noun  TWICE      1
#  3        속       Noun  TWICE      1
#  4        에       Josa  TWICE      1
#  ..     ...        ...    ...    ...
#  237    Boy      Alpha  TWICE      1
#  238      I      Alpha  TWICE      1
#  239     am      Alpha  TWICE      1
#  240   your      Alpha  TWICE      1
#  241   fool      Alpha  TWICE      1
#
#  [242 rows x 4 columns],          0         1   type  count
#  0       매일      Noun  TWICE      1
#  1      울리는      Verb  TWICE      1
#  2        벨  Modifier  TWICE      1
#  3        벨  Modifier  TWICE      1
#  4        벨      Noun  TWICE      1
#  ..     ...       ...    ...    ...
#  388    and     Alpha  TWICE      1
#  389   then     Alpha  TWICE      1
#  390   baby     Alpha  TWICE      1
#  391  CHEER     Alpha  TWICE      1
#  392     UP     Alpha  TWICE      1
#
#  [393 rows x 4 columns],          0            1   type  count
#  0        I        Alpha  TWICE      1
#  1        ’  Punctuation  TWICE      1
#  2        m        Alpha  TWICE      1
#  3       so        Alpha  TWICE      1
#  4    sorry        Alpha  TWICE      1
#  ..     ...          ...    ...    ...
#  280      나         Noun  TWICE      1
#  281      의         Josa  TWICE      1
#  282      이         Noun  TWICE      1
#  283      품         Noun  TWICE      1
#  284     으로         Josa  TWICE      1
#
#  [285 rows x 4 columns],              0            1   type  count
#  0           시간         Noun  TWICE      1
#  1            아         Josa  TWICE      1
#  2           10       Number  TWICE      1
#  3            ,  Punctuation  TWICE      1
#  4            9       Number  TWICE      1
#  ..         ...          ...    ...    ...
#  492          2       Number  TWICE      1
#  493          ,  Punctuation  TWICE      1
#  494          1       Number  TWICE      1
#  495  Touchdown        Alpha  TWICE      1
#  496          !  Punctuation  TWICE      1
#
#  [497 rows x 4 columns],           0         1   type  count
#  0       툭하면      Noun  TWICE      1
#  1         톡      Noun  TWICE      1
#  2        나를      Verb  TWICE      1
#  3      건드려도      Verb  TWICE      1
#  4       툭하면      Noun  TWICE      1
#  ..      ...       ...    ...    ...
#  220       열  Modifier  TWICE      1
#  221      어도      Noun  TWICE      1
#  222      될까      Verb  TWICE      1
#  223      no     Alpha  TWICE      1
#  224  really     Alpha  TWICE      1
#
#  [225 rows x 4 columns],            0            1   type  count
#  0    Welcome        Alpha  TWICE      1
#  1         to        Alpha  TWICE      1
#  2         my        Alpha  TWICE      1
#  3      world        Alpha  TWICE      1
#  4    welcome        Alpha  TWICE      1
#  ..       ...          ...    ...    ...
#  258     here        Alpha  TWICE      1
#  259       we        Alpha  TWICE      1
#  260       go        Alpha  TWICE      1
#  261      now        Alpha  TWICE      1
#  262        !  Punctuation  TWICE      1
#
#  [263 rows x 4 columns],            0          1   type  count
#  0    Goodbye      Alpha  TWICE      1
#  1         라도       Josa  TWICE      1
#  2        괜찮아  Adjective  TWICE      1
#  3          내       Noun  TWICE      1
#  4        헤드폰       Noun  TWICE      1
#  ..       ...        ...    ...    ...
#  199      모르는       Verb  TWICE      1
#  200       사람       Noun  TWICE      1
#  201        이       Josa  TWICE      1
#  202        된       Verb  TWICE      1
#  203       거야       Eomi  TWICE      1
#
#  [204 rows x 4 columns],            0            1   type  count
#  0          [  Punctuation  TWICE      1
#  1     Nayeon        Alpha  TWICE      1
#  2          ]  Punctuation  TWICE      1
#  3          I        Alpha  TWICE      1
#  4          ’  Punctuation  TWICE      1
#  ...      ...          ...    ...    ...
#  1263   gonna        Alpha  TWICE      1
#  1264      be        Alpha  TWICE      1
#  1265       a        Alpha  TWICE      1
#  1266    star        Alpha  TWICE      1
#  1267    star        Alpha  TWICE      1
#
#  [1268 rows x 4 columns],         0            1   type  count
#  0    이러지도         Verb  TWICE      1
#  1       못   VerbPrefix  TWICE      1
#  2     하는데         Verb  TWICE      1
#  3    저러지도         Verb  TWICE      1
#  4       못   VerbPrefix  TWICE      1
#  ..    ...          ...    ...    ...
#  381     '  Punctuation  TWICE      1
#  382     d        Alpha  TWICE      1
#  383    be        Alpha  TWICE      1
#  384    my        Alpha  TWICE      1
#  385  baby        Alpha  TWICE      1
#
#  [386 rows x 4 columns],         0            1   type  count
#  0    Baby        Alpha  TWICE      1
#  1       ,  Punctuation  TWICE      1
#  2       I        Alpha  TWICE      1
#  3    know        Alpha  TWICE      1
#  4     you        Alpha  TWICE      1
#  ..    ...          ...    ...    ...
#  330    it        Alpha  TWICE      1
#  331    내게         Verb  TWICE      1
#  332     더         Noun  TWICE      1
#  333   다가와         Verb  TWICE      1
#  334     줘         Verb  TWICE      1
#
#  [335 rows x 4 columns],             0            1   type  count
#  0           축         Noun  TWICE      1
#  1          쳐진         Verb  TWICE      1
#  2          어깨         Noun  TWICE      1
#  3          자신         Noun  TWICE      1
#  4          없는    Adjective  TWICE      1
#  ..        ...          ...    ...    ...
#  268        po        Alpha  TWICE      1
#  269         -  Punctuation  TWICE      1
#  270  ponytail        Alpha  TWICE      1
#  271       보여줘         Verb  TWICE      1
#  272  ponytail        Alpha  TWICE      1
#
#  [273 rows x 4 columns],          0       1   type  count
#  0        우  Adverb  TWICE      1
#  1    jelly   Alpha  TWICE      1
#  2    jelly   Alpha  TWICE      1
#  3        우  Adverb  TWICE      1
#  4    jelly   Alpha  TWICE      1
#  ..     ...     ...    ...    ...
#  373  jelly   Alpha  TWICE      1
#  374  jelly   Alpha  TWICE      1
#  375     oh   Alpha  TWICE      1
#  376     ma   Alpha  TWICE      1
#  377    boy   Alpha  TWICE      1
#
#  [378 rows x 4 columns],         0          1   type  count
#  0       내       Noun  TWICE      1
#  1       맘       Noun  TWICE      1
#  2       이       Josa  TWICE      1
#  3      하루       Noun  TWICE      1
#  4      종일       Noun  TWICE      1
#  ..    ...        ...    ...    ...
#  386  mine      Alpha  TWICE      1
#  387     내       Noun  TWICE      1
#  388     옆       Noun  TWICE      1
#  389     에       Josa  TWICE      1
#  390   있어줘  Adjective  TWICE      1
#
#  [391 rows x 4 columns],        0            1   type  count
#  0     어제         Noun  TWICE      1
#  1      몇         Noun  TWICE      1
#  2      번         Noun  TWICE      1
#  3     이고         Josa  TWICE      1
#  4     연습         Noun  TWICE      1
#  ..   ...          ...    ...    ...
#  442   oh        Alpha  TWICE      1
#  443   oh        Alpha  TWICE      1
#  444  woo        Alpha  TWICE      1
#  445   oh        Alpha  TWICE      1
#  446    )  Punctuation  TWICE      1
#
#  [447 rows x 4 columns],          0          1   type  count
#  0      You      Alpha  TWICE      1
#  1    gotta      Alpha  TWICE      1
#  2     know      Alpha  TWICE      1
#  3     that      Alpha  TWICE      1
#  4      you      Alpha  TWICE      1
#  ..     ...        ...    ...    ...
#  296      댄       Verb  TWICE      1
#  297     아주       Noun  TWICE      1
#  298    특별한  Adjective  TWICE      1
#  299      걸       Noun  TWICE      1
#  300      요       Josa  TWICE      1
#
#  [301 rows x 4 columns],          0            1   type  count
#  0      열두시         Noun  TWICE      1
#  1        가         Josa  TWICE      1
#  2       되면         Verb  TWICE      1
#  3      닫혀요         Verb  TWICE      1
#  4       조금         Noun  TWICE      1
#  ..     ...          ...    ...    ...
#  485      ,  Punctuation  TWICE      1
#  486  knock        Alpha  TWICE      1
#  487     on        Alpha  TWICE      1
#  488     my        Alpha  TWICE      1
#  489   door        Alpha  TWICE      1
#
#  [490 rows x 4 columns],         0       1   type  count
#  0     함께한    Verb  TWICE      1
#  1      시간    Noun  TWICE      1
#  2       들  Suffix  TWICE      1
#  3       이    Josa  TWICE      1
#  4      매일    Noun  TWICE      1
#  ..    ...     ...    ...    ...
#  241     내    Noun  TWICE      1
#  242    나비    Noun  TWICE      1
#  243     가    Josa  TWICE      1
#  244  되어줘요    Verb  TWICE      1
#  245    그대    Noun  TWICE      1
#
#  [246 rows x 4 columns],           0      1   type  count
#  0    Trying  Alpha  TWICE      1
#  1        to  Alpha  TWICE      1
#  2       let  Alpha  TWICE      1
#  3       you  Alpha  TWICE      1
#  4      know  Alpha  TWICE      1
#  ..      ...    ...    ...    ...
#  337    Sign  Alpha  TWICE      1
#  338       을   Josa  TWICE      1
#  339      보내   Verb  TWICE      1
#  340  signal  Alpha  TWICE      1
#  341      보내   Verb  TWICE      1
#
#  [342 rows x 4 columns],        0     1   type  count
#  0      뭐  Noun  TWICE      1
#  1    하길래  Verb  TWICE      1
#  2     종일  Noun  TWICE      1
#  3     연락  Noun  TWICE      1
#  4      이  Josa  TWICE      1
#  ..   ...   ...    ...    ...
#  286   연락  Noun  TWICE      1
#  287    좀  Noun  TWICE      1
#  288    해  Noun  TWICE      1
#  289   바보  Noun  TWICE      1
#  290    야  Josa  TWICE      1
#
#  [291 rows x 4 columns],         0            1   type  count
#  0    Only        Alpha  TWICE      1
#  1       ,  Punctuation  TWICE      1
#  2      oh        Alpha  TWICE      1
#  3    only        Alpha  TWICE      1
#  4       ,  Punctuation  TWICE      1
#  ..    ...          ...    ...    ...
#  470     ,  Punctuation  TWICE      1
#  471  only        Alpha  TWICE      1
#  472     너         Noun  TWICE      1
#  473  Only        Alpha  TWICE      1
#  474     너         Noun  TWICE      1
#
#  [475 rows x 4 columns],         0            1   type  count
#  0     Hey        Alpha  TWICE      1
#  1       !  Punctuation  TWICE      1
#  2      It        Alpha  TWICE      1
#  3       '  Punctuation  TWICE      1
#  4       s        Alpha  TWICE      1
#  ..    ...          ...    ...    ...
#  286     내         Noun  TWICE      1
#  287     가         Josa  TWICE      1
#  288   특별히    Adjective  TWICE      1
#  289    허락         Noun  TWICE      1
#  290  해줬잖아         Verb  TWICE      1
#
#  [291 rows x 4 columns],          0       1   type  count
#  0    12345  Number  TWICE      1
#  1        네    Noun  TWICE      1
#  2        가    Josa  TWICE      1
#  3     걸어온다    Verb  TWICE      1
#  4       심장    Noun  TWICE      1
#  ..     ...     ...    ...    ...
#  344      다  Adverb  TWICE      1
#  345     녹아    Verb  TWICE      1
#  346     버릴    Verb  TWICE      1
#  347      걸    Noun  TWICE      1
#  348   yeah   Alpha  TWICE      1
#
#  [349 rows x 4 columns],         0       1   type  count
#  0       내    Noun  TWICE      1
#  1       가    Josa  TWICE      1
#  2       그    Noun  TWICE      1
#  3       댈    Verb  TWICE      1
#  4     얼마나    Noun  TWICE      1
#  ..    ...     ...    ...    ...
#  285     너    Noun  TWICE      1
#  286    에게    Josa  TWICE      1
#  287     다  Adverb  TWICE      1
#  288  보여주고    Verb  TWICE      1
#  289    싶어    Verb  TWICE      1
#
#  [290 rows x 4 columns],          0          1   type  count
#  0      설렌다  Adjective  TWICE      1
#  1       Me      Alpha  TWICE      1
#  2    Likey      Alpha  TWICE      1
#  3       Me      Alpha  TWICE      1
#  4    Likey      Alpha  TWICE      1
#  ..     ...        ...    ...    ...
#  322  Likey      Alpha  TWICE      1
#  323   두근두근     Adverb  TWICE      1
#  324     두근     Adverb  TWICE      1
#  325  Heart      Alpha  TWICE      1
#  326  Heart      Alpha  TWICE      1
#
#  [327 rows x 4 columns],         0          1   type  count
#  0      처음       Noun  TWICE      1
#  1       엔       Josa  TWICE      1
#  2      아무       Noun  TWICE      1
#  3      느낌       Noun  TWICE      1
#  4    없었는데  Adjective  TWICE      1
#  ..    ...        ...    ...    ...
#  265    앞서       Noun  TWICE      1
#  266    토끼       Noun  TWICE      1
#  267     와       Josa  TWICE      1
#  268   거북이       Noun  TWICE      1
#  269    처럼       Josa  TWICE      1
#
#  [270 rows x 4 columns],         0      1   type  count
#  0      그땐   Noun  TWICE      1
#  1     가지마   Verb  TWICE      1
#  2     가지마   Verb  TWICE      1
#  3    난생처음   Noun  TWICE      1
#  4      나답   Noun  TWICE      1
#  ..    ...    ...    ...    ...
#  320  Baby  Alpha  TWICE      1
#  321    대체   Noun  TWICE      1
#  322     너   Noun  TWICE      1
#  323    어디   Noun  TWICE      1
#  324    갔니   Verb  TWICE      1
#
#  [325 rows x 4 columns],        0      1   type  count
#  0     Oh  Alpha  TWICE      1
#  1     My  Alpha  TWICE      1
#  2    God  Alpha  TWICE      1
#  3      두   Noun  TWICE      1
#  4      볼   Noun  TWICE      1
#  ..   ...    ...    ...    ...
#  322    만   Josa  TWICE      1
#  323   몰라   Verb  TWICE      1
#  324   Oh  Alpha  TWICE      1
#  325   My  Alpha  TWICE      1
#  326  God  Alpha  TWICE      1
#
#  [327 rows x 4 columns],      0      1   type  count
#  0    F  Alpha  TWICE      1
#  1    A  Alpha  TWICE      1
#  2    S  Alpha  TWICE      1
#  3    T  Alpha  TWICE      1
#  4    F  Alpha  TWICE      1
#  ..  ..    ...    ...    ...
#  452  R  Alpha  TWICE      1
#  453  W  Alpha  TWICE      1
#  454  A  Alpha  TWICE      1
#  455  R  Alpha  TWICE      1
#  456  D  Alpha  TWICE      1
#
#  [457 rows x 4 columns],          0      1   type  count
#  0        D  Alpha  TWICE      1
#  1        D  Alpha  TWICE      1
#  2        D  Alpha  TWICE      1
#  3    Dance  Alpha  TWICE      1
#  4       on  Alpha  TWICE      1
#  ..     ...    ...    ...    ...
#  360      이   Josa  TWICE      1
#  361   Yeah  Alpha  TWICE      1
#  362   Yeah  Alpha  TWICE      1
#  363   Yeah  Alpha  TWICE      1
#  364   Yeah  Alpha  TWICE      1
#
#  [365 rows x 4 columns],         0          1   type  count
#  0       매   Modifier  TWICE      1
#  1       일   Modifier  TWICE      1
#  2      매일       Noun  TWICE      1
#  3     들리는       Verb  TWICE      1
#  4      투정       Noun  TWICE      1
#  ..    ...        ...    ...    ...
#  363    좋아  Adjective  TWICE      1
#  364    지금       Noun  TWICE      1
#  365     의       Josa  TWICE      1
#  366     난       Noun  TWICE      1
#  367  Yeah      Alpha  TWICE      1
#
#  [368 rows x 4 columns],         0      1   type  count
#  0    Look  Alpha  TWICE      1
#  1      at  Alpha  TWICE      1
#  2      me  Alpha  TWICE      1
#  3    Look  Alpha  TWICE      1
#  4      at  Alpha  TWICE      1
#  ..    ...    ...    ...    ...
#  371    at  Alpha  TWICE      1
#  372    me  Alpha  TWICE      1
#  373     날   Noun  TWICE      1
#  374    바라   Verb  TWICE      1
#  375   바라봐   Verb  TWICE      1
#
#  [376 rows x 4 columns],           0            1   type  count
#  0         I        Alpha  TWICE      1
#  1       can        Alpha  TWICE      1
#  2         '  Punctuation  TWICE      1
#  3         t        Alpha  TWICE      1
#  4    handle        Alpha  TWICE      1
#  ..      ...          ...    ...    ...
#  297       '  Punctuation  TWICE      1
#  298    빙글빙글       Adverb  TWICE      1
#  299      빙글       Adverb  TWICE      1
#  300  Rollin        Alpha  TWICE      1
#  301       '  Punctuation  TWICE      1
#
#  [302 rows x 4 columns],        0           1   type  count
#  0    떨리는        Verb  TWICE      1
#  1    목소리        Noun  TWICE      1
#  2    맘대로      Adverb  TWICE      1
#  3      안  VerbPrefix  TWICE      1
#  4      돼        Verb  TWICE      1
#  ..   ...         ...    ...    ...
#  361    이        Josa  TWICE      1
#  362    물        Noun  TWICE      1
#  363  들어갈        Verb  TWICE      1
#  364    수        Noun  TWICE      1
#  365   있게   Adjective  TWICE      1
#
#  [366 rows x 4 columns],         0            1   type  count
#  0       힘         Noun  TWICE      1
#  1       을         Josa  TWICE      1
#  2       내         Noun  TWICE      1
#  3    Baby        Alpha  TWICE      1
#  4     don        Alpha  TWICE      1
#  ..    ...          ...    ...    ...
#  272   don        Alpha  TWICE      1
#  273     '  Punctuation  TWICE      1
#  274     t        Alpha  TWICE      1
#  275  give        Alpha  TWICE      1
#  276    up        Alpha  TWICE      1
#
#  [277 rows x 4 columns],         0     1   type  count
#  0       잠  Noun  TWICE      1
#  1       이  Josa  TWICE      1
#  2      오지  Noun  TWICE      1
#  3      않는  Verb  TWICE      1
#  4      오늘  Noun  TWICE      1
#  ..    ...   ...    ...    ...
#  332     널  Noun  TWICE      1
#  333  감싸줄게  Verb  TWICE      1
#  334     널  Noun  TWICE      1
#  335    내게  Verb  TWICE      1
#  336    담아  Verb  TWICE      1
#
#  [337 rows x 4 columns],          0          1   type  count
#  0       오늘       Noun  TWICE      1
#  1       하루       Noun  TWICE      1
#  2        는       Josa  TWICE      1
#  3     어땠나요  Adjective  TWICE      1
#  4       힘든  Adjective  TWICE      1
#  ..     ...        ...    ...    ...
#  208      잘       Verb  TWICE      1
#  209      자       Noun  TWICE      1
#  210      요       Josa  TWICE      1
#  211   Good      Alpha  TWICE      1
#  212  night      Alpha  TWICE      1
#
#  [213 rows x 4 columns],          0          1   type  count
#  0     Yeah      Alpha  TWICE      1
#  1     Yeah      Alpha  TWICE      1
#  2     Yeah      Alpha  TWICE      1
#  3     Yeah      Alpha  TWICE      1
#  4     Come      Alpha  TWICE      1
#  ..     ...        ...    ...    ...
#  391   mine      Alpha  TWICE      1
#  392  좋아한다고  Adjective  TWICE      1
#  393      말       Noun  TWICE      1
#  394     할래       Verb  TWICE      1
#  395  반했으니까  Adjective  TWICE      1
#
#  [396 rows x 4 columns],        0          1   type  count
#  0     매년       Noun  TWICE      1
#  1    12월     Number  TWICE      1
#  2     달력       Noun  TWICE      1
#  3      을       Josa  TWICE      1
#  4     넘길       Verb  TWICE      1
#  ..   ...        ...    ...    ...
#  229    가       Josa  TWICE      1
#  230    내       Noun  TWICE      1
#  231    곁       Noun  TWICE      1
#  232    에       Josa  TWICE      1
#  233  있으니  Adjective  TWICE      1
#
#  [234 rows x 4 columns],          0            1   type  count
#  0       매일         Noun  TWICE      1
#  1       같이         Josa  TWICE      1
#  2       영화         Noun  TWICE      1
#  3        속         Noun  TWICE      1
#  4      에서나         Josa  TWICE      1
#  ..     ...          ...    ...    ...
#  399   love        Alpha  TWICE      1
#  400      ?  Punctuation  TWICE      1
#  401      I        Alpha  TWICE      1
#  402  wanna        Alpha  TWICE      1
#  403   know        Alpha  TWICE      1
#
#  [404 rows x 4 columns],        0            1   type  count
#  0     Ah        Alpha  TWICE      1
#  1      -  Punctuation  TWICE      1
#  2    ooh        Alpha  TWICE      1
#  3      -  Punctuation  TWICE      1
#  4     ah        Alpha  TWICE      1
#  ..   ...          ...    ...    ...
#  356   Ah        Alpha  TWICE      1
#  357    -  Punctuation  TWICE      1
#  358  ooh        Alpha  TWICE      1
#  359    -  Punctuation  TWICE      1
#  360   ah        Alpha  TWICE      1
#
#  [361 rows x 4 columns],        0      1   type  count
#  0     매일   Noun  TWICE      1
#  1    걸었던   Verb  TWICE      1
#  2      그   Noun  TWICE      1
#  3     길이   Noun  TWICE      1
#  4     분명   Noun  TWICE      1
#  ..   ...    ...    ...    ...
#  397   na  Alpha  TWICE      1
#  398   na  Alpha  TWICE      1
#  399   na  Alpha  TWICE      1
#  400   na  Alpha  TWICE      1
#  401   na  Alpha  TWICE      1
#
#  [402 rows x 4 columns],           0      1   type  count
#  0         네   Noun  TWICE      1
#  1         가   Josa  TWICE      1
#  2        나를   Verb  TWICE      1
#  3         봐   Verb  TWICE      1
#  4        Oh  Alpha  TWICE      1
#  ..      ...    ...    ...    ...
#  312       너   Noun  TWICE      1
#  313       와   Josa  TWICE      1
#  314       나   Noun  TWICE      1
#  315       의   Josa  TWICE      1
#  316  DEJAVU  Alpha  TWICE      1
#
#  [317 rows x 4 columns],          0            1   type  count
#  0    Would        Alpha  TWICE      1
#  1      you        Alpha  TWICE      1
#  2       be        Alpha  TWICE      1
#  3       my        Alpha  TWICE      1
#  4     love        Alpha  TWICE      1
#  ..     ...          ...    ...    ...
#  242      ?  Punctuation  TWICE      1
#  243    Say        Alpha  TWICE      1
#  244   yeah        Alpha  TWICE      1
#  245    Say        Alpha  TWICE      1
#  246    yes        Alpha  TWICE      1
#
#  [247 rows x 4 columns],          0      1   type  count
#  0     Love  Alpha  TWICE      1
#  1       me  Alpha  TWICE      1
#  2     baby  Alpha  TWICE      1
#  3       첨부   Noun  TWICE      1
#  4        터   Noun  TWICE      1
#  ..     ...    ...    ...    ...
#  381     on  Alpha  TWICE      1
#  382    you  Alpha  TWICE      1
#  383  Stuck  Alpha  TWICE      1
#  384     on  Alpha  TWICE      1
#  385    you  Alpha  TWICE      1
#
#  [386 rows x 4 columns],          0      1   type  count
#  0       나나   Noun  TWICE      1
#  1       나나   Noun  TWICE      1
#  2       나나   Noun  TWICE      1
#  3        나   Josa  TWICE      1
#  4       나나   Noun  TWICE      1
#  ..     ...    ...    ...    ...
#  356      s  Alpha  TWICE      1
#  357  dance  Alpha  TWICE      1
#  358    the  Alpha  TWICE      1
#  359  night  Alpha  TWICE      1
#  360   away  Alpha  TWICE      1
#
#  [361 rows x 4 columns],             0            1   type  count
#  0          바빠    Adjective  TWICE      1
#  1           ,  Punctuation  TWICE      1
#  2          오늘         Noun  TWICE      1
#  3           은         Josa  TWICE      1
#  4         피곤해    Adjective  TWICE      1
#  ..        ...          ...    ...    ...
#  414         고         Josa  TWICE      1
#  415        싶어         Verb  TWICE      1
#  416         ,  Punctuation  TWICE      1
#  417      Just        Alpha  TWICE      1
#  418  chilllax        Alpha  TWICE      1
#
#  [419 rows x 4 columns],            0      1   type  count
#  0        You  Alpha  TWICE      1
#  1        got  Alpha  TWICE      1
#  2         me  Alpha  TWICE      1
#  3       shot  Alpha  TWICE      1
#  4    through  Alpha  TWICE      1
#  ..       ...    ...    ...    ...
#  382       me  Alpha  TWICE      1
#  383     shot  Alpha  TWICE      1
#  384  through  Alpha  TWICE      1
#  385      the  Alpha  TWICE      1
#  386    heart  Alpha  TWICE      1
#
#  [387 rows x 4 columns],         0            1   type  count
#  0     Hey        Alpha  TWICE      1
#  1     boy        Alpha  TWICE      1
#  2    Look        Alpha  TWICE      1
#  3       ,  Punctuation  TWICE      1
#  4       I        Alpha  TWICE      1
#  ..    ...          ...    ...    ...
#  412     자         Noun  TWICE      1
#  413    선택         Noun  TWICE      1
#  414     은         Josa  TWICE      1
#  415     네         Noun  TWICE      1
#  416     맘         Noun  TWICE      1
#
#  [417 rows x 4 columns],          0      1   type  count
#  0       우리   Noun  TWICE      1
#  1       사이   Noun  TWICE      1
#  2        를   Josa  TWICE      1
#  3        좀   Noun  TWICE      1
#  4      바꾸고   Verb  TWICE      1
#  ..     ...    ...    ...    ...
#  224    you  Alpha  TWICE      1
#  225  gotta  Alpha  TWICE      1
#  226    let  Alpha  TWICE      1
#  227     me  Alpha  TWICE      1
#  228   know  Alpha  TWICE      1
#
#  [229 rows x 4 columns],         0            1   type  count
#  0      It        Alpha  TWICE      1
#  1       '  Punctuation  TWICE      1
#  2       s        Alpha  TWICE      1
#  3       a        Alpha  TWICE      1
#  4    good        Alpha  TWICE      1
#  ..    ...          ...    ...    ...
#  184     이         Josa  TWICE      1
#  185   시원한    Adjective  TWICE      1
#  186    바람         Noun  TWICE      1
#  187     이         Josa  TWICE      1
#  188    불어         Noun  TWICE      1
#
#  [189 rows x 4 columns],             0            1   type  count
#  0          We        Alpha  TWICE      1
#  1         all        Alpha  TWICE      1
#  2        have        Alpha  TWICE      1
#  3          so        Alpha  TWICE      1
#  4        many        Alpha  TWICE      1
#  ..        ...          ...    ...    ...
#  250   nothing        Alpha  TWICE      1
#  251         '  Punctuation  TWICE      1
#  252         s        Alpha  TWICE      1
#  253  stopping        Alpha  TWICE      1
#  254        me        Alpha  TWICE      1
#
#  [255 rows x 4 columns],           0          1   type  count
#  0         새       Noun  TWICE      1
#  1       빨갛게  Adjective  TWICE      1
#  2        물들       Verb  TWICE      1
#  3         너       Noun  TWICE      1
#  4         와       Josa  TWICE      1
#  ..      ...        ...    ...    ...
#  185       너       Noun  TWICE      1
#  186       와       Josa  TWICE      1
#  187       나       Noun  TWICE      1
#  188       의       Josa  TWICE      1
#  189  Sunset      Alpha  TWICE      1
#
#  [190 rows x 4 columns],        0           1   type  count
#  0      두  Determiner  TWICE      1
#  1     근대        Noun  TWICE      1
#  2      는        Josa  TWICE      1
#  3     그때        Noun  TWICE      1
#  4     기억        Noun  TWICE      1
#  ..   ...         ...    ...    ...
#  194    에        Josa  TWICE      1
#  195  있을게   Adjective  TWICE      1
#  196    곁        Noun  TWICE      1
#  197    에        Josa  TWICE      1
#  198  있을게   Adjective  TWICE      1
#
#  [199 rows x 4 columns],              0      1   type  count
#  0         Like  Alpha  TWICE      1
#  1            a  Alpha  TWICE      1
#  2    bulldozer  Alpha  TWICE      1
#  3         Like  Alpha  TWICE      1
#  4            a  Alpha  TWICE      1
#  ..         ...    ...    ...    ...
#  224         바보   Noun  TWICE      1
#  225         같이   Josa  TWICE      1
#  226      기다리지는   Verb  TWICE      1
#  227         않을   Verb  TWICE      1
#  228         거야   Eomi  TWICE      1
#
#  [229 rows x 4 columns],          0      1   type  count
#  0      The  Alpha  TWICE      1
#  1     best  Alpha  TWICE      1
#  2    thing  Alpha  TWICE      1
#  3        I  Alpha  TWICE      1
#  4     ever  Alpha  TWICE      1
#  ..     ...    ...    ...    ...
#  300   best  Alpha  TWICE      1
#  301  thing  Alpha  TWICE      1
#  302      I  Alpha  TWICE      1
#  303   ever  Alpha  TWICE      1
#  304    did  Alpha  TWICE      1
#
#  [305 rows x 4 columns],        0      1   type  count
#  0    보이지   Noun  TWICE      1
#  1     않던   Verb  TWICE      1
#  2      이   Noun  TWICE      1
#  3      길   Noun  TWICE      1
#  4      의   Josa  TWICE      1
#  ..   ...    ...    ...    ...
#  266    의   Josa  TWICE      1
#  267    별   Noun  TWICE      1
#  268   Be  Alpha  TWICE      1
#  269   as  Alpha  TWICE      1
#  270  one  Alpha  TWICE      1
#
#  [271 rows x 4 columns],          0      1   type  count
#  0       지금   Noun  TWICE      1
#  1       하늘   Noun  TWICE      1
#  2       구름   Noun  TWICE      1
#  3        색   Noun  TWICE      1
#  4        은   Josa  TWICE      1
#  ..     ...    ...    ...    ...
#  325     지금   Noun  TWICE      1
#  326      너   Noun  TWICE      1
#  327    에게로   Josa  TWICE      1
#  328     갈래   Noun  TWICE      1
#  329  Fancy  Alpha  TWICE      1
#
#  [330 rows x 4 columns],          0      1   type  count
#  0    Stuck  Alpha  TWICE      1
#  1       in  Alpha  TWICE      1
#  2       my  Alpha  TWICE      1
#  3     head  Alpha  TWICE      1
#  4     like  Alpha  TWICE      1
#  ..     ...    ...    ...    ...
#  450   like  Alpha  TWICE      1
#  451     La  Alpha  TWICE      1
#  452     la  Alpha  TWICE      1
#  453     la  Alpha  TWICE      1
#  454     la  Alpha  TWICE      1
#
#  [455 rows x 4 columns],          0         1   type  count
#  0       언제      Noun  TWICE      1
#  1       부턴      Josa  TWICE      1
#  2        지      Verb  TWICE      1
#  3     모르겠어      Verb  TWICE      1
#  4        오  Modifier  TWICE      1
#  ..     ...       ...    ...    ...
#  196   like     Alpha  TWICE      1
#  197     us     Alpha  TWICE      1
#  198  Girls     Alpha  TWICE      1
#  199   like     Alpha  TWICE      1
#  200     us     Alpha  TWICE      1
#
#  [201 rows x 4 columns],         0      1   type  count
#  0      모든   Noun  TWICE      1
#  1       건   Noun  TWICE      1
#  2     느껴진   Verb  TWICE      1
#  3     그대로   Noun  TWICE      1
#  4       나   Noun  TWICE      1
#  ..    ...    ...    ...    ...
#  286  Burn  Alpha  TWICE      1
#  287    it  Alpha  TWICE      1
#  288    up  Alpha  TWICE      1
#  289   hot  Alpha  TWICE      1
#  290  baby  Alpha  TWICE      1
#
#  [291 rows x 4 columns],          0      1   type  count
#  0     Just  Alpha  TWICE      1
#  1     feel  Alpha  TWICE      1
#  2       it  Alpha  TWICE      1
#  3       달빛   Noun  TWICE      1
#  4        속   Noun  TWICE      1
#  ..     ...    ...    ...    ...
#  450     ll  Alpha  TWICE      1
#  451  never  Alpha  TWICE      1
#  452   lose  Alpha  TWICE      1
#  453    our  Alpha  TWICE      1
#  454   vibe  Alpha  TWICE      1
#
#  [455 rows x 4 columns],        0      1   type  count
#  0     눈치   Noun  TWICE      1
#  1      채   Noun  TWICE      1
#  2     버린   Verb  TWICE      1
#  3     걸까   Verb  TWICE      1
#  4      새   Noun  TWICE      1
#  ..   ...    ...    ...    ...
#  256   여기   Noun  TWICE      1
#  257    내   Noun  TWICE      1
#  258   마음   Noun  TWICE      1
#  259  Ooh  Alpha  TWICE      1
#  260  boy  Alpha  TWICE      1
#
#  [261 rows x 4 columns],            0            1   type  count
#  0         그런    Adjective  TWICE      1
#  1          날         Noun  TWICE      1
#  2          이         Josa  TWICE      1
#  3         있어    Adjective  TWICE      1
#  4        갑자기         Noun  TWICE      1
#  ..       ...          ...    ...    ...
#  303        ,  Punctuation  TWICE      1
#  304        I        Alpha  TWICE      1
#  305     feel        Alpha  TWICE      1
#  306       so        Alpha  TWICE      1
#  307  special        Alpha  TWICE      1
#
#  [308 rows x 4 columns],           0      1   type  count
#  0      Tell  Alpha  TWICE      1
#  1        me  Alpha  TWICE      1
#  2      tell  Alpha  TWICE      1
#  3        me  Alpha  TWICE      1
#  4      tell  Alpha  TWICE      1
#  ..      ...    ...    ...    ...
#  276     get  Alpha  TWICE      1
#  277      to  Alpha  TWICE      1
#  278     the  Alpha  TWICE      1
#  279  purple  Alpha  TWICE      1
#  280    line  Alpha  TWICE      1
#
#  [281 rows x 4 columns],          0      1   type  count
#  0      Hey  Alpha  TWICE      1
#  1    might  Alpha  TWICE      1
#  2      get  Alpha  TWICE      1
#  3     loud  Alpha  TWICE      1
#  4      Hey  Alpha  TWICE      1
#  ..     ...    ...    ...    ...
#  351    마지막   Noun  TWICE      1
#  352     경고   Noun  TWICE      1
#  353  Might  Alpha  TWICE      1
#  354    get  Alpha  TWICE      1
#  355   loud  Alpha  TWICE      1
#
#  [356 rows x 4 columns],         0      1   type  count
#  0      Ah  Alpha  TWICE      1
#  1      ha  Alpha  TWICE      1
#  2      ah  Alpha  TWICE      1
#  3      ha  Alpha  TWICE      1
#  4      ah  Alpha  TWICE      1
#  ..    ...    ...    ...    ...
#  452     I  Alpha  TWICE      1
#  453  like  Alpha  TWICE      1
#  454    it  Alpha  TWICE      1
#  455  like  Alpha  TWICE      1
#  456  that  Alpha  TWICE      1
#
#  [457 rows x 4 columns],          0      1   type  count
#  0       매일   Noun  TWICE      1
#  1       매일   Noun  TWICE      1
#  2        네   Noun  TWICE      1
#  3       이름   Noun  TWICE      1
#  4        을   Josa  TWICE      1
#  ..     ...    ...    ...    ...
#  294  Crazy  Alpha  TWICE      1
#  295   love  Alpha  TWICE      1
#  296      I  Alpha  TWICE      1
#  297   hate  Alpha  TWICE      1
#  298    you  Alpha  TWICE      1
#
#  [299 rows x 4 columns],         0      1   type  count
#  0    This  Alpha  TWICE      1
#  1      is  Alpha  TWICE      1
#  2     for  Alpha  TWICE      1
#  3     you  Alpha  TWICE      1
#  4     You  Alpha  TWICE      1
#  ..    ...    ...    ...    ...
#  186    할게   Verb  TWICE      1
#  187  This  Alpha  TWICE      1
#  188    is  Alpha  TWICE      1
#  189   for  Alpha  TWICE      1
#  190   you  Alpha  TWICE      1
#
#  [191 rows x 4 columns],                 0      1   type  count
#  0              변치   Noun  TWICE      1
#  1              않는   Verb  TWICE      1
#  2               이   Noun  TWICE      1
#  3               맘   Noun  TWICE      1
#  4               은   Josa  TWICE      1
#  ..            ...    ...    ...    ...
#  445         break  Alpha  TWICE      1
#  446  breakthrough  Alpha  TWICE      1
#  447         break  Alpha  TWICE      1
#  448         break  Alpha  TWICE      1
#  449  breakthrough  Alpha  TWICE      1
#
#  [450 rows x 4 columns],         0          1   type  count
#  0       I      Alpha  TWICE      1
#  1    know      Alpha  TWICE      1
#  2       I      Alpha  TWICE      1
#  3    want      Alpha  TWICE      1
#  4      it      Alpha  TWICE      1
#  ..    ...        ...    ...    ...
#  334  more      Alpha  TWICE      1
#  335   그러니  Adjective  TWICE      1
#  336     한       Verb  TWICE      1
#  337     번       Noun  TWICE      1
#  338     더       Noun  TWICE      1
#
#  [339 rows x 4 columns],         0      1   type  count
#  0      나도   Verb  TWICE      1
#  1     모르게   Verb  TWICE      1
#  2       너   Noun  TWICE      1
#  3       의   Josa  TWICE      1
#  4      호흡   Noun  TWICE      1
#  ..    ...    ...    ...    ...
#  392    re  Alpha  TWICE      1
#  393    my  Alpha  TWICE      1
#  394  only  Alpha  TWICE      1
#  395  only  Alpha  TWICE      1
#  396   one  Alpha  TWICE      1
#
#  [397 rows x 4 columns],             0      1   type  count
#  0          Uh  Alpha  TWICE      1
#  1        yeah  Alpha  TWICE      1
#  2        yeah  Alpha  TWICE      1
#  3        yeah  Alpha  TWICE      1
#  4          ay  Alpha  TWICE      1
#  ..        ...    ...    ...    ...
#  314         I  Alpha  TWICE      1
#  315      feel  Alpha  TWICE      1
#  316      like  Alpha  TWICE      1
#  317         a  Alpha  TWICE      1
#  318  firework  Alpha  TWICE      1
#
#  [319 rows x 4 columns],           0          1   type  count
#  0         저       Noun  TWICE      1
#  1        멀리       Noun  TWICE      1
#  2         서       Verb  TWICE      1
#  3        있는  Adjective  TWICE      1
#  4         넌       Noun  TWICE      1
#  ..      ...        ...    ...    ...
#  488      do      Alpha  TWICE      1
#  489      it      Alpha  TWICE      1
#  490    like      Alpha  TWICE      1
#  491     you      Alpha  TWICE      1
#  492  should      Alpha  TWICE      1
#
#  [493 rows x 4 columns],           0          1   type  count
#  0       아파도  Adjective  TWICE      1
#  1       괜찮은  Adjective  TWICE      1
#  2         척       Noun  TWICE      1
#  3         다     Adverb  TWICE      1
#  4         큰       Verb  TWICE      1
#  ..      ...        ...    ...    ...
#  224       채       Noun  TWICE      1
#  225       로       Josa  TWICE      1
#  226      내게       Verb  TWICE      1
#  227    스며드는       Verb  TWICE      1
#  228  Shadow      Alpha  TWICE      1
#
#  [229 rows x 4 columns],          0            1   type  count
#  0        3       Number  TWICE      1
#  1        A        Alpha  TWICE      1
#  2        .  Punctuation  TWICE      1
#  3        M        Alpha  TWICE      1
#  4        .  Punctuation  TWICE      1
#  ..     ...          ...    ...    ...
#  188      ’  Punctuation  TWICE      1
#  189      t        Alpha  TWICE      1
#  190   call        Alpha  TWICE      1
#  191     me        Alpha  TWICE      1
#  192  again        Alpha  TWICE      1
#
#  [193 rows x 4 columns],           0      1   type  count
#  0        Yo  Alpha  TWICE      1
#  1      aayy  Alpha  TWICE      1
#  2     sweet  Alpha  TWICE      1
#  3    summer  Alpha  TWICE      1
#  4       day  Alpha  TWICE      1
# ...
#  3     챙겨줘    Verb  SEVENTEEN(세븐틴)      1
#  4    yeah   Alpha  SEVENTEEN(세븐틴)      1
#  ..    ...     ...             ...    ...
#  341    얼어    Verb  SEVENTEEN(세븐틴)      1
#  342    버린    Verb  SEVENTEEN(세븐틴)      1
#  343    세상    Noun  SEVENTEEN(세븐틴)      1
#  344     우  Adverb  SEVENTEEN(세븐틴)      1
#  345     워    Noun  SEVENTEEN(세븐틴)      1
#
#  [346 rows x 4 columns],               0          1            type  count
#  0            거짓       Noun  SEVENTEEN(세븐틴)      1
#  1          Burn      Alpha  SEVENTEEN(세븐틴)      1
#  2            up      Alpha  SEVENTEEN(세븐틴)      1
#  3            우릴       Noun  SEVENTEEN(세븐틴)      1
#  4            믿어       Verb  SEVENTEEN(세븐틴)      1
#  ..          ...        ...             ...    ...
#  402           숨       Noun  SEVENTEEN(세븐틴)      1
#  403          쉬듯       Verb  SEVENTEEN(세븐틴)      1
#  404       자연스러워  Adjective  SEVENTEEN(세븐틴)      1
#  405         영원한  Adjective  SEVENTEEN(세븐틴)      1
#  406  Dedication      Alpha  SEVENTEEN(세븐틴)      1
#
#  [407 rows x 4 columns],            0          1            type  count
#  0    BRRRRRR      Alpha  SEVENTEEN(세븐틴)      1
#  1          내       Noun  SEVENTEEN(세븐틴)      1
#  2        머릿속       Noun  SEVENTEEN(세븐틴)      1
#  3          을       Josa  SEVENTEEN(세븐틴)      1
#  4       파고들어       Verb  SEVENTEEN(세븐틴)      1
#  ..       ...        ...             ...    ...
#  356       차게       Verb  SEVENTEEN(세븐틴)      1
#  357        너       Noun  SEVENTEEN(세븐틴)      1
#  358        를       Josa  SEVENTEEN(세븐틴)      1
#  359       원해  Adjective  SEVENTEEN(세븐틴)      1
#  360       원해  Adjective  SEVENTEEN(세븐틴)      1
#
#  [361 rows x 4 columns],          0       1            type  count
#  0    Youth   Alpha  SEVENTEEN(세븐틴)      1
#  1       우리    Noun  SEVENTEEN(세븐틴)      1
#  2       함께  Adverb  SEVENTEEN(세븐틴)      1
#  3       걷는    Verb  SEVENTEEN(세븐틴)      1
#  4       우리    Noun  SEVENTEEN(세븐틴)      1
#  ..     ...     ...             ...    ...
#  282      널    Noun  SEVENTEEN(세븐틴)      1
#  283     위해    Noun  SEVENTEEN(세븐틴)      1
#  284     My   Alpha  SEVENTEEN(세븐틴)      1
#  285      9  Number  SEVENTEEN(세븐틴)      1
#  286   teen   Alpha  SEVENTEEN(세븐틴)      1
#
#  [287 rows x 4 columns],          0      1            type  count
#  0      HIT  Alpha  SEVENTEEN(세븐틴)      1
#  1    SOUND  Alpha  SEVENTEEN(세븐틴)      1
#  2      HIT  Alpha  SEVENTEEN(세븐틴)      1
#  3      HIT  Alpha  SEVENTEEN(세븐틴)      1
#  4      HIT  Alpha  SEVENTEEN(세븐틴)      1
#  ..     ...    ...             ...    ...
#  316    HIT  Alpha  SEVENTEEN(세븐틴)      1
#  317    HIT  Alpha  SEVENTEEN(세븐틴)      1
#  318    HIT  Alpha  SEVENTEEN(세븐틴)      1
#  319    HIT  Alpha  SEVENTEEN(세븐틴)      1
#  320  SOUND  Alpha  SEVENTEEN(세븐틴)      1
#
#  [321 rows x 4 columns],         0      1            type  count
#  0       넌   Noun  SEVENTEEN(세븐틴)      1
#  1       내   Noun  SEVENTEEN(세븐틴)      1
#  2      기억   Noun  SEVENTEEN(세븐틴)      1
#  3       을   Josa  SEVENTEEN(세븐틴)      1
#  4     지워야   Verb  SEVENTEEN(세븐틴)      1
#  ..    ...    ...             ...    ...
#  387  love  Alpha  SEVENTEEN(세븐틴)      1
#  388   the  Alpha  SEVENTEEN(세븐틴)      1
#  389   way  Alpha  SEVENTEEN(세븐틴)      1
#  390     I  Alpha  SEVENTEEN(세븐틴)      1
#  391  love  Alpha  SEVENTEEN(세븐틴)      1
#
#  [392 rows x 4 columns],        0            1            type  count
#  0      네         Noun  SEVENTEEN(세븐틴)      1
#  1      가         Josa  SEVENTEEN(세븐틴)      1
#  2     싫어    Adjective  SEVENTEEN(세븐틴)      1
#  3      난         Noun  SEVENTEEN(세븐틴)      1
#  4      네         Noun  SEVENTEEN(세븐틴)      1
#  ..   ...          ...             ...    ...
#  212    )  Punctuation  SEVENTEEN(세븐틴)      1
#  213    또         Noun  SEVENTEEN(세븐틴)      1
#  214  거짓말         Noun  SEVENTEEN(세븐틴)      1
#  215    을         Josa  SEVENTEEN(세븐틴)      1
#  216    해         Noun  SEVENTEEN(세븐틴)      1
#
#  [217 rows x 4 columns],        0     1            type  count
#  0    누군가  Noun  SEVENTEEN(세븐틴)      1
#  1      가  Josa  SEVENTEEN(세븐틴)      1
#  2     어디  Noun  SEVENTEEN(세븐틴)      1
#  3      선  Noun  SEVENTEEN(세븐틴)      1
#  4      가  Josa  SEVENTEEN(세븐틴)      1
#  ..   ...   ...             ...    ...
#  378    내  Noun  SEVENTEEN(세븐틴)      1
#  379   기쁨  Noun  SEVENTEEN(세븐틴)      1
#  380    을  Josa  SEVENTEEN(세븐틴)      1
#  381   주고  Verb  SEVENTEEN(세븐틴)      1
#  382   싶어  Verb  SEVENTEEN(세븐틴)      1
#
#  [383 rows x 4 columns],        0     1            type  count
#  0      난  Noun  SEVENTEEN(세븐틴)      1
#  1      잠  Noun  SEVENTEEN(세븐틴)      1
#  2      을  Josa  SEVENTEEN(세븐틴)      1
#  3      잘  Verb  SEVENTEEN(세븐틴)      1
#  4      때  Noun  SEVENTEEN(세븐틴)      1
#  ..   ...   ...             ...    ...
#  252   멈출  Verb  SEVENTEEN(세븐틴)      1
#  253    때  Noun  SEVENTEEN(세븐틴)      1
#  254   까지  Josa  SEVENTEEN(세븐틴)      1
#  255  끝나지  Verb  SEVENTEEN(세븐틴)      1
#  256   않아  Verb  SEVENTEEN(세븐틴)      1
#
#  [257 rows x 4 columns],        0       1            type  count
#  0      나    Noun  SEVENTEEN(세븐틴)      1
#  1     에게    Josa  SEVENTEEN(세븐틴)      1
#  2      두    Noun  SEVENTEEN(세븐틴)      1
#  3     번째  Suffix  SEVENTEEN(세븐틴)      1
#  4     지금    Noun  SEVENTEEN(세븐틴)      1
#  ..   ...     ...             ...    ...
#  259   에도    Josa  SEVENTEEN(세븐틴)      1
#  260   그때    Noun  SEVENTEEN(세븐틴)      1
#  261    도    Josa  SEVENTEEN(세븐틴)      1
#  262    너    Noun  SEVENTEEN(세븐틴)      1
#  263  에게로    Josa  SEVENTEEN(세븐틴)      1
#
#  [264 rows x 4 columns],               0          1            type  count
#  0            너무     Adverb  SEVENTEEN(세븐틴)      1
#  1            멀어  Adjective  SEVENTEEN(세븐틴)      1
#  2            우리       Noun  SEVENTEEN(세븐틴)      1
#  3             의       Josa  SEVENTEEN(세븐틴)      1
#  4            거리       Noun  SEVENTEEN(세븐틴)      1
#  ..          ...        ...             ...    ...
#  226          세계       Noun  SEVENTEEN(세븐틴)      1
#  227          에서       Josa  SEVENTEEN(세븐틴)      1
#  228  Electronic      Alpha  SEVENTEEN(세븐틴)      1
#  229     network      Alpha  SEVENTEEN(세븐틴)      1
#  230        love      Alpha  SEVENTEEN(세븐틴)      1
#
#  [231 rows x 4 columns],         0       1            type  count
#  0       길    Noun  SEVENTEEN(세븐틴)      1
#  1      막마    Verb  SEVENTEEN(세븐틴)      1
#  2      전부    Noun  SEVENTEEN(세븐틴)      1
#  3       다  Adverb  SEVENTEEN(세븐틴)      1
#  4      비켜    Verb  SEVENTEEN(세븐틴)      1
#  ..    ...     ...             ...    ...
#  387  back   Alpha  SEVENTEEN(세븐틴)      1
#  388  back   Alpha  SEVENTEEN(세븐틴)      1
#  389  Back   Alpha  SEVENTEEN(세븐틴)      1
#  390    it   Alpha  SEVENTEEN(세븐틴)      1
#  391    up   Alpha  SEVENTEEN(세븐틴)      1
#
#  [392 rows x 4 columns],          0          1            type  count
#  0        U      Alpha  SEVENTEEN(세븐틴)      1
#  1      괜찮아  Adjective  SEVENTEEN(세븐틴)      1
#  2       문제       Noun  SEVENTEEN(세븐틴)      1
#  3        는       Josa  SEVENTEEN(세븐틴)      1
#  4        풀       Noun  SEVENTEEN(세븐틴)      1
#  ..     ...        ...             ...    ...
#  342  Lucky      Alpha  SEVENTEEN(세븐틴)      1
#  343     내일       Noun  SEVENTEEN(세븐틴)      1
#  344      도       Josa  SEVENTEEN(세븐틴)      1
#  345  Lucky      Alpha  SEVENTEEN(세븐틴)      1
#  346  Lucky      Alpha  SEVENTEEN(세븐틴)      1
#
#  [347 rows x 4 columns],          0          1            type  count
#  0      Yeh      Alpha  SEVENTEEN(세븐틴)      1
#  1      지루한  Adjective  SEVENTEEN(세븐틴)      1
#  2       일상       Noun  SEVENTEEN(세븐틴)      1
#  3        의       Josa  SEVENTEEN(세븐틴)      1
#  4       속박       Noun  SEVENTEEN(세븐틴)      1
#  ..     ...        ...             ...    ...
#  407     지금       Noun  SEVENTEEN(세븐틴)      1
#  408      이       Noun  SEVENTEEN(세븐틴)      1
#  409     순간       Noun  SEVENTEEN(세븐틴)      1
#  410      에       Josa  SEVENTEEN(세븐틴)      1
#  411  Shoot      Alpha  SEVENTEEN(세븐틴)      1
#
#  [412 rows x 4 columns],           0      1            type  count
#  0     Happy  Alpha  SEVENTEEN(세븐틴)      1
#  1    Ending  Alpha  SEVENTEEN(세븐틴)      1
#  2     Happy  Alpha  SEVENTEEN(세븐틴)      1
#  3    Ending  Alpha  SEVENTEEN(세븐틴)      1
#  4       Yeh  Alpha  SEVENTEEN(세븐틴)      1
#  ..      ...    ...             ...    ...
#  348     Woo  Alpha  SEVENTEEN(세븐틴)      1
#  349   Happy  Alpha  SEVENTEEN(세븐틴)      1
#  350  Ending  Alpha  SEVENTEEN(세븐틴)      1
#  351   Happy  Alpha  SEVENTEEN(세븐틴)      1
#  352  Ending  Alpha  SEVENTEEN(세븐틴)      1
#
#  [353 rows x 4 columns],         0          1            type  count
#  0    따뜻하게  Adjective  SEVENTEEN(세븐틴)      1
#  1      나를       Verb  SEVENTEEN(세븐틴)      1
#  2    감싸오네       Verb  SEVENTEEN(세븐틴)      1
#  3      기분       Noun  SEVENTEEN(세븐틴)      1
#  4      좋은  Adjective  SEVENTEEN(세븐틴)      1
#  ..    ...        ...             ...    ...
#  327     맘       Noun  SEVENTEEN(세븐틴)      1
#  328    온통       Noun  SEVENTEEN(세븐틴)      1
#  329   너와나       Noun  SEVENTEEN(세븐틴)      1
#  330    뿐인  Adjective  SEVENTEEN(세븐틴)      1
#  331     밤       Noun  SEVENTEEN(세븐틴)      1
#
#  [332 rows x 4 columns],         0      1            type  count
#  0      하나   Noun  SEVENTEEN(세븐틴)      1
#  1       둘   Noun  SEVENTEEN(세븐틴)      1
#  2       셋   Noun  SEVENTEEN(세븐틴)      1
#  3       넷   Noun  SEVENTEEN(세븐틴)      1
#  4    Left  Alpha  SEVENTEEN(세븐틴)      1
#  ..    ...    ...             ...    ...
#  409     넷   Noun  SEVENTEEN(세븐틴)      1
#  410     넷   Noun  SEVENTEEN(세븐틴)      1
#  411     둘   Noun  SEVENTEEN(세븐틴)      1
#  412     셋   Noun  SEVENTEEN(세븐틴)      1
#  413     넷   Noun  SEVENTEEN(세븐틴)      1
#
#  [414 rows x 4 columns],             0      1            type  count
#  0          Eh  Alpha  SEVENTEEN(세븐틴)      1
#  1          oh  Alpha  SEVENTEEN(세븐틴)      1
#  2          eh  Alpha  SEVENTEEN(세븐틴)      1
#  3          oh  Alpha  SEVENTEEN(세븐틴)      1
#  4         지워진   Verb  SEVENTEEN(세븐틴)      1
#  ..        ...    ...             ...    ...
#  364  Fearless  Alpha  SEVENTEEN(세븐틴)      1
#  365        Eh  Alpha  SEVENTEEN(세븐틴)      1
#  366        oh  Alpha  SEVENTEEN(세븐틴)      1
#  367        eh  Alpha  SEVENTEEN(세븐틴)      1
#  368        oh  Alpha  SEVENTEEN(세븐틴)      1
#
#  [369 rows x 4 columns],          0          1            type  count
#  0       가끔       Noun  SEVENTEEN(세븐틴)      1
#  1        씩     Suffix  SEVENTEEN(세븐틴)      1
#  2        네       Noun  SEVENTEEN(세븐틴)      1
#  3       생각       Noun  SEVENTEEN(세븐틴)      1
#  4       나서       Verb  SEVENTEEN(세븐틴)      1
#  ..     ...        ...             ...    ...
#  256  아무렇지도  Adjective  SEVENTEEN(세븐틴)      1
#  257     않게       Verb  SEVENTEEN(세븐틴)      1
#  258     아주       Noun  SEVENTEEN(세븐틴)      1
#  259     아픈  Adjective  SEVENTEEN(세븐틴)      1
#  260      밤       Noun  SEVENTEEN(세븐틴)      1
#
#  [261 rows x 4 columns],        0      1            type  count
#  0    Yeh  Alpha  SEVENTEEN(세븐틴)      1
#  1      발   Noun  SEVENTEEN(세븐틴)      1
#  2     맞춰   Verb  SEVENTEEN(세븐틴)      1
#  3     어디   Noun  SEVENTEEN(세븐틴)      1
#  4      론   Noun  SEVENTEEN(세븐틴)      1
#  ..   ...    ...             ...    ...
#  290   oh  Alpha  SEVENTEEN(세븐틴)      1
#  291  가까이   Noun  SEVENTEEN(세븐틴)      1
#  292   My  Alpha  SEVENTEEN(세븐틴)      1
#  293   my  Alpha  SEVENTEEN(세븐틴)      1
#  294  way  Alpha  SEVENTEEN(세븐틴)      1
#
#  [295 rows x 4 columns],          0          1            type  count
#  0       맘속       Noun  SEVENTEEN(세븐틴)      1
#  1        엔       Josa  SEVENTEEN(세븐틴)      1
#  2    어린아이가       Verb  SEVENTEEN(세븐틴)      1
#  3       있어  Adjective  SEVENTEEN(세븐틴)      1
#  4       오늘       Noun  SEVENTEEN(세븐틴)      1
#  ..     ...        ...             ...    ...
#  273     모습       Noun  SEVENTEEN(세븐틴)      1
#  274    그대로       Noun  SEVENTEEN(세븐틴)      1
#  275     어른       Noun  SEVENTEEN(세븐틴)      1
#  276     아이       Noun  SEVENTEEN(세븐틴)      1
#  277     처럼       Josa  SEVENTEEN(세븐틴)      1
#
#  [278 rows x 4 columns],        0         1            type  count
#  0     오랜  Modifier  SEVENTEEN(세븐틴)      1
#  1      만      Noun  SEVENTEEN(세븐틴)      1
#  2      에      Josa  SEVENTEEN(세븐틴)      1
#  3    만나는      Verb  SEVENTEEN(세븐틴)      1
#  4     친구      Noun  SEVENTEEN(세븐틴)      1
#  ..   ...       ...             ...    ...
#  272    거      Noun  SEVENTEEN(세븐틴)      1
#  273   예요      Josa  SEVENTEEN(세븐틴)      1
#  274   같이    Adverb  SEVENTEEN(세븐틴)      1
#  275   가요      Noun  SEVENTEEN(세븐틴)      1
#  276   Oh     Alpha  SEVENTEEN(세븐틴)      1
#
#  [277 rows x 4 columns],              0      1            type  count
#  0            널   Noun  SEVENTEEN(세븐틴)      1
#  1           만난   Noun  SEVENTEEN(세븐틴)      1
#  2           그날   Noun  SEVENTEEN(세븐틴)      1
#  3           부터   Josa  SEVENTEEN(세븐틴)      1
#  4           시작   Noun  SEVENTEEN(세븐틴)      1
#  ..         ...    ...             ...    ...
#  244        two  Alpha  SEVENTEEN(세븐틴)      1
#  245        the  Alpha  SEVENTEEN(세븐틴)      1
#  246       same  Alpha  SEVENTEEN(세븐틴)      1
#  247         as  Alpha  SEVENTEEN(세븐틴)      1
#  248  seventeen  Alpha  SEVENTEEN(세븐틴)      1
#
#  [249 rows x 4 columns],              0        1            type  count
#  0    SEVENTEEN    Alpha  SEVENTEEN(세븐틴)      1
#  1        Right    Alpha  SEVENTEEN(세븐틴)      1
#  2         here    Alpha  SEVENTEEN(세븐틴)      1
#  3           9회   Number  SEVENTEEN(세븐틴)      1
#  4            말  Foreign  SEVENTEEN(세븐틴)      1
#  ..         ...      ...             ...    ...
#  360         보자     Verb  SEVENTEEN(세븐틴)      1
#  361          내     Noun  SEVENTEEN(세븐틴)      1
#  362         인생     Noun  SEVENTEEN(세븐틴)      1
#  363          은     Josa  SEVENTEEN(세븐틴)      1
#  364         홈런     Noun  SEVENTEEN(세븐틴)      1
#
#  [365 rows x 4 columns],        0      1            type  count
#  0      뭘   Noun  SEVENTEEN(세븐틴)      1
#  1     자꾸   Noun  SEVENTEEN(세븐틴)      1
#  2     주저   Noun  SEVENTEEN(세븐틴)      1
#  3      해   Verb  SEVENTEEN(세븐틴)      1
#  4     감정   Noun  SEVENTEEN(세븐틴)      1
#  ..   ...    ...             ...    ...
#  353   oh  Alpha  SEVENTEEN(세븐틴)      1
#  354   oh  Alpha  SEVENTEEN(세븐틴)      1
#  355  Yeh  Alpha  SEVENTEEN(세븐틴)      1
#  356  yeh  Alpha  SEVENTEEN(세븐틴)      1
#  357   oh  Alpha  SEVENTEEN(세븐틴)      1
#
#  [358 rows x 4 columns],          0      1            type  count
#  0      Hey  Alpha  SEVENTEEN(세븐틴)      1
#  1    buddy  Alpha  SEVENTEEN(세븐틴)      1
#  2       지금   Noun  SEVENTEEN(세븐틴)      1
#  3        몇   Noun  SEVENTEEN(세븐틴)      1
#  4       시야   Noun  SEVENTEEN(세븐틴)      1
#  ..     ...    ...             ...    ...
#  299    Hey  Alpha  SEVENTEEN(세븐틴)      1
#  300    hey  Alpha  SEVENTEEN(세븐틴)      1
#  301     우린   Noun  SEVENTEEN(세븐틴)      1
#  302     친구   Noun  SEVENTEEN(세븐틴)      1
#  303      야   Josa  SEVENTEEN(세븐틴)      1
#
#  [304 rows x 4 columns],           0          1            type  count
#  0    아슬아슬하게  Adjective  SEVENTEEN(세븐틴)      1
#  1         선       Noun  SEVENTEEN(세븐틴)      1
#  2         을       Josa  SEVENTEEN(세븐틴)      1
#  3         타       Noun  SEVENTEEN(세븐틴)      1
#  4       Woo      Alpha  SEVENTEEN(세븐틴)      1
#  ..      ...        ...             ...    ...
#  206      마음       Noun  SEVENTEEN(세븐틴)      1
#  207       에       Josa  SEVENTEEN(세븐틴)      1
#  208       불       Noun  SEVENTEEN(세븐틴)      1
#  209       을       Josa  SEVENTEEN(세븐틴)      1
#  210      지펴       Verb  SEVENTEEN(세븐틴)      1
#
#  [211 rows x 4 columns],          0            1            type  count
#  0        I        Alpha  SEVENTEEN(세븐틴)      1
#  1        ’  Punctuation  SEVENTEEN(세븐틴)      1
#  2        m        Alpha  SEVENTEEN(세븐틴)      1
#  3    ready        Alpha  SEVENTEEN(세븐틴)      1
#  4      for        Alpha  SEVENTEEN(세븐틴)      1
#  ..     ...          ...             ...    ...
#  325     Ah        Alpha  SEVENTEEN(세븐틴)      1
#  326      !  Punctuation  SEVENTEEN(세븐틴)      1
#  327   Love        Alpha  SEVENTEEN(세븐틴)      1
#  328     is        Alpha  SEVENTEEN(세븐틴)      1
#  329    you        Alpha  SEVENTEEN(세븐틴)      1
#
#  [330 rows x 4 columns],       0           1            type  count
#  0     내        Noun  SEVENTEEN(세븐틴)      1
#  1    사랑        Noun  SEVENTEEN(세븐틴)      1
#  2     은        Josa  SEVENTEEN(세븐틴)      1
#  3    겨우        Noun  SEVENTEEN(세븐틴)      1
#  4     이  Determiner  SEVENTEEN(세븐틴)      1
#  ..   ..         ...             ...    ...
#  328   너        Noun  SEVENTEEN(세븐틴)      1
#  329   의        Josa  SEVENTEEN(세븐틴)      1
#  330  모든        Noun  SEVENTEEN(세븐틴)      1
#  331   날        Noun  SEVENTEEN(세븐틴)      1
#  332   에        Josa  SEVENTEEN(세븐틴)      1
#
#  [333 rows x 4 columns]]

# %%
# "저장공간" 변수의 내용을 데이터프레임 형식으로 변환해서 "분석통합" 변수에 저장한다.
분석통합 = pd.concat(저장공간)

# %%
# "분석통합" 변수의 저장 내용 확인
분석통합
# Out:
#         0            1            type  count
# 0     Hey        Alpha       BLACKPINK      1
# 1     boy        Alpha       BLACKPINK      1
# 2    Make        Alpha       BLACKPINK      1
# 3       ’  Punctuation       BLACKPINK      1
# 4      em        Alpha       BLACKPINK      1
# ..    ...          ...             ...    ...
# 328     너         Noun  SEVENTEEN(세븐틴)      1
# 329     의         Josa  SEVENTEEN(세븐틴)      1
# 330    모든         Noun  SEVENTEEN(세븐틴)      1
# 331     날         Noun  SEVENTEEN(세븐틴)      1
# 332     에         Josa  SEVENTEEN(세븐틴)      1
#
# [207752 rows x 4 columns]

# %%
# "분석통합" 변수의 컬럼(열) 이름 변경
분석통합.columns = ["형태소", "품사", "그룹명", "카운트"]

# %%
# "분석통합" 변수의 저장 내용 확인
분석통합
# Out:
#       형태소           품사             그룹명  카운트
# 0     Hey        Alpha       BLACKPINK    1
# 1     boy        Alpha       BLACKPINK    1
# 2    Make        Alpha       BLACKPINK    1
# 3       ’  Punctuation       BLACKPINK    1
# 4      em        Alpha       BLACKPINK    1
# ..    ...          ...             ...  ...
# 328     너         Noun  SEVENTEEN(세븐틴)    1
# 329     의         Josa  SEVENTEEN(세븐틴)    1
# 330    모든         Noun  SEVENTEEN(세븐틴)    1
# 331     날         Noun  SEVENTEEN(세븐틴)    1
# 332     에         Josa  SEVENTEEN(세븐틴)    1
#
# [207752 rows x 4 columns]

# %%
# "분석통합" 변수의 내용을 형태소, 품사, 분류가 같은 것을 합치고, 카운트의 총합을 구해서 "그룹통합" 변수에 저장한다.
그룹통합 = 분석통합.groupby(['형태소', '품사', "그룹명"])['카운트'].sum()

# %%
# "그룹통합" 변수의 저장 내용 확인
그룹통합
# Out:
# 형태소  품사           그룹명
# \n   Foreign      Red Velvet(레드벨벳)      2
# !    Punctuation  BLACKPINK             1
#                   BTS(방탄소년단)          178
#                   EXO                 137
#                   NCT 127               7
#                                      ...
# ＂    Foreign      BTS(방탄소년단)           33
#                   EXO                   2
#                   Red Velvet(레드벨벳)      6
#                   SEVENTEEN(세븐틴)        2
# ＋    Foreign      BTS(방탄소년단)            2
# Name: 카운트, Length: 33629, dtype: int64

# %%
# "그룹통합" 변수의 내용을 데이터프레임 형식으로 변환해서 "그룹통합" 변수에 저장한다.
그룹통합 = pd.DataFrame(그룹통합)

# %%
# "그룹통합" 변수의 저장 내용 확인
그룹통합
# Out:
#                                   카운트
# 형태소 품사          그룹명
# \n  Foreign     Red Velvet(레드벨벳)    2
# !   Punctuation BLACKPINK           1
#                 BTS(방탄소년단)        178
#                 EXO               137
#                 NCT 127             7
# ...                               ...
# ＂   Foreign     BTS(방탄소년단)         33
#                 EXO                 2
#                 Red Velvet(레드벨벳)    6
#                 SEVENTEEN(세븐틴)      2
# ＋   Foreign     BTS(방탄소년단)          2
#
# [33629 rows x 1 columns]

# %%
# "그룹통합" 변수의 내용을 "형태소분석결과.csv" 파일로 저장한다.
# header는 컬럼(열) 정보의 포함 여부이다.
# encoding은 문자코드를 선택하는 것이다. python에서는 기본적으로 utf-8(유니코드)를 사용한다.

그룹통합.to_csv('형태소분석결과.csv', header='true', encoding='utf-8')
